# %% [markdown]
# <b>Workforce Planning</b>

# %%
# Input data
Days = {'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'}
Shifts = {'StartMon', 'StartTue', 'StartWed', 'StartThu', 'StartFri', 'StartSat', 'StartSun', 'Weekend', 'PartTime'}
DaysInShift = {
    'StartMon' : {'Mon', 'Tue', 'Wed', 'Thu', 'Fri'},
    'StartTue' : {'Tue', 'Wed', 'Thu', 'Fri', 'Sat'},
    'StartWed' : {'Wed', 'Thu', 'Fri', 'Sat', 'Sun'},
    'StartThu' : {'Mon', 'Thu', 'Fri', 'Sat', 'Sun'},
    'StartFri' : {'Mon', 'Tue', 'Fri', 'Sat', 'Sun'},
    'StartSat' : {'Mon', 'Tue', 'Wed', 'Sat', 'Sun'},
    'StartSun' : {'Mon', 'Tue', 'Wed', 'Thu', 'Sun'},
    'Weekend' : {'Fri', 'Sat', 'Sun'},
    'PartTime' : {'Wed', 'Thu'}
}
Wages = {
    'StartMon' : 500,
    'StartTue' : 500,
    'StartWed' : 550,
    'StartThu' : 550,
    'StartFri' : 550,
    'StartSat' : 550,
    'StartSun' : 550,
    'Weekend' : 250,
    'PartTime' : 175
}
Demand = {'Mon' : 14, 'Tue' : 13, 'Wed' : 15, 'Thu' : 16, 'Fri' : 19, 'Sat' : 18, 'Sun' : 11}

# %%
from docplex.mp.model import Model
mdl = Model()

# %%
# variables
Workers = mdl.continuous_var_dict(Shifts, lb=0, name=Shifts)

# %%
# objective
mdl.minimize(mdl.sum(Wages[s]*Workers[s] for s in Shifts))

# %%
# demand constraints for each day
for d in Days:
    mdl.add(mdl.sum(Workers[s] for s in Shifts if d in DaysInShift[s]) >= Demand[d])

# %%
# solve
mdl.solve()
mdl.get_solve_details()
# Out:
# docplex.mp.SolveDetails(time=0,status='optimal')

# %%
mdl.print_solution()
# Out:
# objective: 11050.000
#   StartSat=4.000
#   StartTue=4.000
#   StartThu=5.000
#   Weekend=5.000
#   StartMon=5.000
#   PartTime=2.000

# %%
print(sum(Workers[s].solution_value for s in Shifts))
# Out:
# 25.0
