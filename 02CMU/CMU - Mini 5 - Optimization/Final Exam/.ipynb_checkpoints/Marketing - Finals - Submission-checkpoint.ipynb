# %%
Price = {'P1':35, 'P2':45, 'P3': 28}
Campaigns = range(0,11)
Products = Price.keys()

# import math for e
import math

# Pre-compute demand for each product i and campaign j:
Demand = {}
for j in Campaigns:
        Demand['P1',j] = 500*(1+math.log(1+j,10))
        Demand['P2',j] = 350*(1+math.log(1+2*j,10))
        Demand['P3',j] = 600*(1+math.log(1+1.1*j,10))

# %%
Demand
# Out:
# {('P1', 0): 500.0,
#  ('P2', 0): 350.0,
#  ('P3', 0): 600.0,
#  ('P1', 1): 650.5149978319906,
#  ('P2', 1): 516.9924391518819,
#  ('P3', 1): 793.3315768403515,
#  ('P1', 2): 738.5606273598312,
#  ('P2', 2): 594.6395015176065,
#  ('P3', 2): 903.0899869919435,
#  ('P1', 3): 801.0299956639811,
#  ('P2', 3): 645.7843140049898,
#  ('P3', 3): 980.081073347752,
#  ('P1', 4): 849.4850021680094,
#  ('P2', 4): 683.9848783037637,
#  ('P3', 4): 1039.4362558937812,
#  ('P1', 5): 889.0756251918217,
#  ('P2', 5): 714.4874398053787,
#  ('P3', 5): 1087.7480139857132,
#  ('P1', 6): 922.5490200071283,
#  ('P2', 6): 739.880173307393,
#  ('P3', 6): 1128.4881553684747,
#  ('P1', 7): 951.5449934959717,
#  ('P2', 7): 761.6319406694885,
#  ('P3', 7): 1163.7115515711712,
#  ('P1', 8): 977.1212547196624,
#  ('P2', 8): 780.657122482396,
#  ('P3', 8): 1194.735645415497,
#  ('P1', 9): 1000.0,
#  ('P2', 9): 797.5637603334901,
#  ('P3', 9): 1222.4558987643743,
#  ('P1', 10): 1020.6963425791124,
#  ('P2', 10): 812.7767531568717,
#  ('P3', 10): 1247.5087476285748}

# %%
# pre-compute the revenue for each product i and campaign j 
Revenue = {}
for i in Products:
    for j in Campaigns:
        Revenue[i,j] = Price[i]*Demand[i,j]

# %%
Revenue
# Out:
# {('P1', 0): 17500.0,
#  ('P1', 1): 22768.024924119673,
#  ('P1', 2): 25849.621957594092,
#  ('P1', 3): 28036.04984823934,
#  ('P1', 4): 29731.975075880327,
#  ('P1', 5): 31117.64688171376,
#  ('P1', 6): 32289.21570024949,
#  ('P1', 7): 33304.07477235901,
#  ('P1', 8): 34199.243915188184,
#  ('P1', 9): 35000.0,
#  ('P1', 10): 35724.37199026893,
#  ('P2', 0): 15750.0,
#  ('P2', 1): 23264.659761834682,
#  ('P2', 2): 26758.77756829229,
#  ('P2', 3): 29060.29413022454,
#  ('P2', 4): 30779.31952366937,
#  ('P2', 5): 32151.93479124204,
#  ('P2', 6): 33294.60779883269,
#  ('P2', 7): 34273.43733012698,
#  ('P2', 8): 35129.57051170782,
#  ('P2', 9): 35890.36921500706,
#  ('P2', 10): 36574.953892059224,
#  ('P3', 0): 16800.0,
#  ('P3', 1): 22213.284151529842,
#  ('P3', 2): 25286.51963577442,
#  ('P3', 3): 27442.270053737055,
#  ('P3', 4): 29104.215165025875,
#  ('P3', 5): 30456.94439159997,
#  ('P3', 6): 31597.668350317294,
#  ('P3', 7): 32583.923443992793,
#  ('P3', 8): 33452.59807163391,
#  ('P3', 9): 34228.76516540248,
#  ('P3', 10): 34930.244933600094}

# %%
from docplex.mp.model import Model
mdl = Model()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# variables
assign = mdl.binary_var_matrix(Products, Campaigns, name='assign')

# %%
# objective
mdl.maximize(mdl.sum(Revenue[i,j]*assign[i,j] for (i,j) in assign.keys()))

# %%
# constraint: each product has one specific number of campaigns
for i in Products:
    mdl.add_constraint(mdl.sum(assign[i,j] for j in Campaigns) == 1)

# %%
# Constraint: there can be at most ten campaigns in total

mdl.add_constraint(mdl.sum(j*assign[i,j] for (i,j) in assign.keys())<=10)
# Out:
# docplex.mp.LinearConstraint[](assign_P1_1+2assign_P1_2+3assign_P1_3+4assign_P1_4+5assign_P1_5+6assign_P1_6+7assign_P1_7+8assign_P1_8+9assign_P1_9+10assign_P1_10+assign_P2_1+2assign_P2_2+3assign_P2_3+4assign_P2_4+5assign_P2_5+6assign_P2_6+7assign_P2_7+8assign_P2_8+9assign_P2_9+10assign_P2_10+assign_P3_1+2assign_P3_2+3assign_P3_3+4assign_P3_4+5assign_P3_5+6assign_P3_6+7assign_P3_7+8assign_P3_8+9assign_P3_9+10assign_P3_10,LE,10)

# %%
# solve
mdl.solve()
mdl.get_solve_details()
# Out:
# docplex.mp.SolveDetails(time=0.00732017,status='integer optimal solution')

# %%
mdl.print_solution()
# Out:
# objective: 86257.639
# status: OPTIMAL_SOLUTION(2)
#   assign_P1_3=1
#   assign_P2_4=1
#   assign_P3_3=1
