# %%
# Transportation Problem: data
Plants = ['Plant 1', 'Plant 2']
Customers = ['Cust A', 'Cust B', 'Cust C']

Cost = {
    ('Plant 1', 'Cust A') : 15,
    ('Plant 1', 'Cust B') : 35,
    ('Plant 1', 'Cust C') : 25,
    ('Plant 2', 'Cust A') : 10,
    ('Plant 2', 'Cust B') : 30,
    ('Plant 2', 'Cust C') : 40
}

Supply = {
    'Plant 1' : 40,
    'Plant 2' : 50    
}

Demand = {
    'Cust A' : 30,
    'Cust B' : 30,
    'Cust C' : 30,
}
