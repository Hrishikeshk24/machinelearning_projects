# %%
from docplex.mp.model import Model
from docplex.util.environment import get_environment
mdl = Model()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
b = mdl.continuous_var(lb=0, name='beef')
c = mdl.continuous_var(lb=0, name='chicken')
r = mdl.continuous_var(lb=0, name='rice')
s = mdl.continuous_var(lb=0, name='spaghetti')

# %%
mdl.minimize(3.2*b + 2.4*c + 2*r + 2.5*s)

# %%
mdl.add_constraint(60*b + 80*c + 25*r + 60*s >= 700)
mdl.add_constraint(20*b +  0*c + 50*r + 20*s >= 700)
mdl.add_constraint(40*b + 20*c + 25*r + 15*s >= 700)
# Out:
# docplex.mp.LinearConstraint[](40beef+20chicken+25rice+15spaghetti,GE,700)

# %%
mdl.solve()
mdl.get_solve_details()
# Out:
# docplex.mp.SolveDetails(time=0.00433707,status='optimal')

# %%
mdl.print_solution()
# Out:
# objective: 56.000
# status: OPTIMAL_SOLUTION(2)
#   beef=11.667
#   rice=9.333
