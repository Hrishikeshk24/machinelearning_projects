# %%
# if pandas is not yet installed, open the Python command prompt (in your CPLEX environment) and run
#   pip install pandas

import pandas as pd
#df_latlong = pd.read_csv("latlong.csv").set_index('County Name')
df_demand = pd.read_csv("demand.csv").set_index('County')
df_dist = pd.read_csv("distance_km.csv")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
Counties = df_demand.index

# %%
Demand = {}
for i in df_demand.index:
    Demand[i] = df_demand['Demand'][i]

# %%
CanServe = {}
for i in Counties:
    CanServe[i,i] = 1

for i in df_dist.index:
    if df_dist['Distance'][i] <= 150:
        c1 = df_dist['County1'][i]
        c2 = df_dist['County2'][i]
        CanServe[c1,c2] = 1
        if not c1 in Counties:
            print("ERROR: "+c1+" not in Counties")
        if not c2 in Counties:
            print("ERROR: "+c2+" not in Counties")

# %%
baselocation = Demand.keys()
destination = Demand.keys()

# %%
from docplex.mp.model import Model
mdl = Model()

# %%
# variables
Selectbase = mdl.binary_var_dict(Counties, name='select base')
Num_Delivery = mdl.continuous_var_dict(CanServe.keys(), lb=0, name='Number of Deliveries')

# %%
# objective
mdl.minimize(mdl.sum(Selectbase[i] for i in Counties))

# %%
# Constraints: establish 10 drones in Pennsylvania

#mdl.add_constraint(mdl.sum(Selectbase[i] for i in Counties) == 10)

# %%
# Constraints: Each drone base can handle at most 10000 deliveries per month

for i in baselocation:
    add=mdl.add_constraint(mdl.sum(Num_Delivery[i,j] for j in destination if (i,j) in CanServe.keys()) <= 10000*Selectbase[i])

# %%
# Demand Constraints at each destination 

for j in destination:
    mdl.add_constraint(mdl.sum(Num_Delivery[i,j] for i in baselocation if (i,j) in CanServe.keys()) == Demand[j])

# %%
# solve
mdl.solve()
mdl.get_solve_details()
# Out:
# docplex.mp.SolveDetails(time=0.0884151,status='integer optimal solution')

# %%
mdl.print_solution()
# Out:
# objective: 11
# status: OPTIMAL_SOLUTION(2)
#   "select base_Adams"=1
#   "select base_Allegheny"=1
#   "select base_Beaver"=1
#   "select base_Carbon"=1
#   "select base_Clinton"=1
#   "select base_Cumberland"=1
#   "select base_Dauphin"=1
#   "select base_Erie"=1
#   "select base_Lancaster"=1
#   "select base_Susquehanna"=1
#   "select base_Wayne"=1
#   "Number of Deliveries_Adams_Adams"=709.000
#   "Number of Deliveries_Allegheny_Allegheny"=5339.000
#   "Number of Deliveries_Clinton_Clinton"=323.000
#   "Number of Deliveries_Erie_Erie"=2339.000
#   "Number of Deliveries_Adams_Berks"=851.000
#   "Number of Deliveries_Adams_Lancaster"=4329.000
#   "Number of Deliveries_Erie_Mercer"=972.000
#   "Number of Deliveries_Erie_Warren"=349.000
#   "Number of Deliveries_Erie_Venango"=459.000
#   "Number of Deliveries_Erie_Butler"=1533.000
#   "Number of Deliveries_Erie_McKean"=363.000
#   "Number of Deliveries_Erie_Armstrong"=575.000
#   "Number of Deliveries_Erie_Jefferson"=377.000
#   "Number of Deliveries_Erie_Beaver"=1422.000
#   "Number of Deliveries_Erie_Forest"=65.000
#   "Number of Deliveries_Erie_Elk"=46.000
#   "Number of Deliveries_Erie_Lawrence"=760.000
#   "Number of Deliveries_Erie_Crawford"=740.000
#   "Number of Deliveries_Cumberland_Adams"=137.000
#   "Number of Deliveries_Cumberland_Chester"=4158.000
#   "Number of Deliveries_Cumberland_Blair"=829.000
#   "Number of Deliveries_Cumberland_Clinton"=4.000
#   "Number of Deliveries_Cumberland_Franklin"=1247.000
#   "Number of Deliveries_Cumberland_York"=3625.000
#   "Number of Deliveries_Susquehanna_Schuylkill"=1236.000
#   "Number of Deliveries_Susquehanna_Monroe"=1344.000
#   "Number of Deliveries_Susquehanna_Union"=375.000
#   "Number of Deliveries_Susquehanna_Luzerne"=2675.000
#   "Number of Deliveries_Susquehanna_Wayne"=441.000
#   "Number of Deliveries_Susquehanna_Lycoming"=968.000
#   "Number of Deliveries_Susquehanna_Pike"=479.000
#   "Number of Deliveries_Susquehanna_Northampton"=2482.000
#   "Number of Deliveries_Allegheny_Greene"=323.000
#   "Number of Deliveries_Allegheny_Blair"=231.000
#   "Number of Deliveries_Allegheny_Westmoreland"=3044.000
#   "Number of Deliveries_Allegheny_Somerset"=648.000
#   "Number of Deliveries_Allegheny_Bedford"=415.000
#   "Number of Deliveries_Dauphin_Berks"=2500.000
#   "Number of Deliveries_Dauphin_Fulton"=124.000
#   "Number of Deliveries_Dauphin_Delaware"=4659.000
#   "Number of Deliveries_Dauphin_Philadelphia"=2717.000
#   "Number of Deliveries_Clinton_Lebanon"=1114.000
#   "Number of Deliveries_Clinton_Potter"=146.000
#   "Number of Deliveries_Clinton_Cumberland"=1962.000
#   "Number of Deliveries_Clinton_Montour"=153.000
#   "Number of Deliveries_Clinton_Dauphin"=2235.000
#   "Number of Deliveries_Clinton_Centre"=1284.000
#   "Number of Deliveries_Clinton_Snyder"=331.000
#   "Number of Deliveries_Clinton_Perry"=384.000
#   "Number of Deliveries_Clinton_Clearfield"=681.000
#   "Number of Deliveries_Clinton_Cameron"=43.000
#   "Number of Deliveries_Clinton_Mifflin"=390.000
#   "Number of Deliveries_Clinton_Elk"=221.000
#   "Number of Deliveries_Clinton_Tioga"=350.000
#   "Number of Deliveries_Clinton_Huntingdon"=383.000
#   "Number of Deliveries_Carbon_Philadelphia"=10000.000
#   "Number of Deliveries_Beaver_Cambria"=1198.000
#   "Number of Deliveries_Beaver_Fayette"=1139.000
#   "Number of Deliveries_Beaver_Allegheny"=4856.000
#   "Number of Deliveries_Beaver_Indiana"=741.000
#   "Number of Deliveries_Beaver_Clarion"=334.000
#   "Number of Deliveries_Beaver_Washington"=1732.000
#   "Number of Deliveries_Lancaster_Juniata"=206.000
#   "Number of Deliveries_Lancaster_Montgomery"=6666.000
#   "Number of Deliveries_Lancaster_Bucks"=3128.000
#   "Number of Deliveries_Wayne_Berks"=78.000
#   "Number of Deliveries_Wayne_Sullivan"=54.000
#   "Number of Deliveries_Wayne_Susquehanna"=362.000
#   "Number of Deliveries_Wayne_Lehigh"=2913.000
#   "Number of Deliveries_Wayne_Wyoming"=236.000
#   "Number of Deliveries_Wayne_Lackawanna"=1787.000
#   "Number of Deliveries_Wayne_Monroe"=72.000
#   "Number of Deliveries_Wayne_Carbon"=544.000
#   "Number of Deliveries_Wayne_Bradford"=522.000
#   "Number of Deliveries_Wayne_Northumberland"=788.000
#   "Number of Deliveries_Wayne_Columbia"=561.000
#   "Number of Deliveries_Wayne_Bucks"=2083.000
