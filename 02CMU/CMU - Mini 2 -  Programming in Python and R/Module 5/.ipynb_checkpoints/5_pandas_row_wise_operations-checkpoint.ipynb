# %% [markdown]
# ## 46-881 Class 5
#
# ### Python pandas: Data Exploration and Wrangling (Part 1)
#
# Amr Farahat
#
# CMU / Tepper
#
# 2022-11-25
#
# ---

# %% [markdown]
# ## Python pandas: Row-wise operations

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("PIT_2021.csv")

# %%
pd.options.display.max_columns = None

# %%
df
# Out:
#        YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK                 FL_DATE  \
# 0      2021      1            10            7   1/10/2021 12:00:00 AM
# 1      2021      1             4            1    1/4/2021 12:00:00 AM
# 2      2021      1             3            7    1/3/2021 12:00:00 AM
# 3      2021      1             3            7    1/3/2021 12:00:00 AM
# 4      2021      1            11            1   1/11/2021 12:00:00 AM
# ...     ...    ...           ...          ...                     ...
# 32615  2021     12            20            1  12/20/2021 12:00:00 AM
# 32616  2021     12            20            1  12/20/2021 12:00:00 AM
# 32617  2021     12            20            1  12/20/2021 12:00:00 AM
# 32618  2021     12            20            1  12/20/2021 12:00:00 AM
# 32619  2021     12            20            1  12/20/2021 12:00:00 AM
#
#       OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN ORIGIN_CITY_NAME ORIGIN_STATE_ABR  \
# ...

# %% [markdown]
# #### Filtering rows by value

# %% [markdown]
# Filter to keep only flights by Southwest Airlines

# %%
df["OP_CARRIER"] == "WN" ## This is just a boolean
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32615    False
# 32616    False
# 32617    False
# 32618    False
# 32619    False
# Name: OP_CARRIER, Length: 32620, dtype: bool

# %%
df[df["OP_CARRIER"] == "WN"]
# Out:
#        YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK                FL_DATE  \
# 97     2021      1             1            5   1/1/2021 12:00:00 AM
# 98     2021      1             1            5   1/1/2021 12:00:00 AM
# 99     2021      1             1            5   1/1/2021 12:00:00 AM
# 100    2021      1             1            5   1/1/2021 12:00:00 AM
# 101    2021      1             1            5   1/1/2021 12:00:00 AM
# ...     ...    ...           ...          ...                    ...
# 31974  2021     12             4            6  12/4/2021 12:00:00 AM
# 31975  2021     12             4            6  12/4/2021 12:00:00 AM
# 31976  2021     12             4            6  12/4/2021 12:00:00 AM
# 31977  2021     12             4            6  12/4/2021 12:00:00 AM
# 31978  2021     12             4            6  12/4/2021 12:00:00 AM
#
#       OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN ORIGIN_CITY_NAME ORIGIN_STATE_ABR  \
# ...

# %% [markdown]
# Direct flights last December to California?

# %%
df[(df["DEST_STATE_ABR"] == "CA") & (df["MONTH"] == 12)]
# Out:
#        YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK                 FL_DATE  \
# 31711  2021     12             1            3   12/1/2021 12:00:00 AM
# 32417  2021     12             2            4   12/2/2021 12:00:00 AM
# 32418  2021     12             3            5   12/3/2021 12:00:00 AM
# 32419  2021     12             5            7   12/5/2021 12:00:00 AM
# 32420  2021     12             6            1   12/6/2021 12:00:00 AM
# 32421  2021     12             9            4   12/9/2021 12:00:00 AM
# 32422  2021     12            10            5  12/10/2021 12:00:00 AM
# 32423  2021     12            12            7  12/12/2021 12:00:00 AM
# 32424  2021     12            13            1  12/13/2021 12:00:00 AM
# 32425  2021     12            16            4  12/16/2021 12:00:00 AM
# 32426  2021     12            17            5  12/17/2021 12:00:00 AM
# 32427  2021     12            18            6  12/18/2021 12:00:00 AM
# ...

# %% [markdown]
# #### Sorting

# %%
df.sort_values(by=["DEP_DELAY"], ascending=False)
# Out:
#        YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK                 FL_DATE  \
# 28913  2021     11            11            4  11/11/2021 12:00:00 AM
# 26530  2021     11            30            2  11/30/2021 12:00:00 AM
# 29965  2021     12            31            5  12/31/2021 12:00:00 AM
# 6278   2021      4            25            7   4/25/2021 12:00:00 AM
# 16283  2021      8             8            7    8/8/2021 12:00:00 AM
# ...     ...    ...           ...          ...                     ...
# 32412  2021     12            27            1  12/27/2021 12:00:00 AM
# 32428  2021     12            19            7  12/19/2021 12:00:00 AM
# 32451  2021     12            18            6  12/18/2021 12:00:00 AM
# 32540  2021     12            27            1  12/27/2021 12:00:00 AM
# 32543  2021     12            27            1  12/27/2021 12:00:00 AM
#
#       OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN ORIGIN_CITY_NAME ORIGIN_STATE_ABR  \
# ...

# %% [markdown]
# ---
# ## END
