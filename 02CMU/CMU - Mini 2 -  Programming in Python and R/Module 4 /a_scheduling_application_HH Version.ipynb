# %% [markdown]
# #### 46-881 Class 4
#
# ### Python Programming: Syntax and Data Structures (Part 2)
#
# Amr Farahat
#
# CMU / Tepper
#
# 2022-11-11
#
# ---

# %% [markdown]
# ## A scheduling application

# %%
import numpy as np
import copy

# %% [markdown]
# #### Defining jobs using dictionaries

# %%
j1 =  {'id': 'Job_1', 'processing_time': 6, 'due_date': 26}
j2 =  {'id': 'Job_2', 'processing_time': 3, 'due_date': 45}
j3 =  {'id': 'Job_3', 'processing_time': 8, 'due_date': 14}
j4 =  {'id': 'Job_4', 'processing_time': 3, 'due_date': 39}
j5 =  {'id': 'Job_5', 'processing_time': 9, 'due_date': 44}
j6 =  {'id': 'Job_6', 'processing_time': 7, 'due_date': 30}
j7 =  {'id': 'Job_7', 'processing_time': 9, 'due_date': 47}
j8 =  {'id': 'Job_8', 'processing_time': 5, 'due_date': 48}
j9 =  {'id': 'Job_9', 'processing_time': 1, 'due_date': 49}
j10 = {'id': 'Job_10', 'processing_time': 3, 'due_date': 28}
j11 = {'id': 'Job_11', 'processing_time': 4, 'due_date': 46}
j12 = {'id': 'Job_12', 'processing_time': 2, 'due_date': 3}
j13 = {'id': 'Job_13', 'processing_time': 5, 'due_date': 46}
j14 = {'id': 'Job_14', 'processing_time': 9, 'due_date': 18}
j15 = {'id': 'Job_15', 'processing_time': 10, 'due_date': 49}
j16 = {'id': 'Job_16', 'processing_time': 1, 'due_date': 24}
j17 = {'id': 'Job_17', 'processing_time': 6, 'due_date': 45}
j18 = {'id': 'Job_18', 'processing_time': 3, 'due_date': 41}
j19 = {'id': 'Job_19', 'processing_time': 10, 'due_date': 74}
j20 = {'id': 'Job_20', 'processing_time': 5, 'due_date': 48}

# %%
list1
# Out:
# [3, 14, 18, 24, 26, 28, 30, 39, 41, 44, 45, 45, 46, 46, 47, 48, 48, 49, 49, 74]

# %%
j1 = {'id': 'Job_12', 'processing_time': 2, 'due_date': 3}
j2 =  {'id': 'Job_3', 'processing_time': 8, 'due_date': 14}
j3 = {'id': 'Job_14', 'processing_time': 9, 'due_date': 18}
j4 = {'id': 'Job_16', 'processing_time': 1, 'due_date': 24}
j5 =  {'id': 'Job_1', 'processing_time': 6, 'due_date': 26}
j6 = {'id': 'Job_10', 'processing_time': 3, 'due_date': 28}
j7 =  {'id': 'Job_6', 'processing_time': 7, 'due_date': 30}
j8 =  {'id': 'Job_4', 'processing_time': 3, 'due_date': 39}
j9 = {'id': 'Job_18', 'processing_time': 3, 'due_date': 41}
j10 =  {'id': 'Job_5', 'processing_time': 9, 'due_date': 44}
j11 =  {'id': 'Job_2', 'processing_time': 3, 'due_date': 45}
j12 = {'id': 'Job_17', 'processing_time': 6, 'due_date': 45}
j13 = {'id': 'Job_13', 'processing_time': 5, 'due_date': 46}
j14 = {'id': 'Job_11', 'processing_time': 4, 'due_date': 46}
j15 =  {'id': 'Job_7', 'processing_time': 9, 'due_date': 47}
j16 =  {'id': 'Job_8', 'processing_time': 5, 'due_date': 48}
j17 = {'id': 'Job_20', 'processing_time': 5, 'due_date': 48}
j18 =  {'id': 'Job_9', 'processing_time': 1, 'due_date': 49}
j19 = {'id': 'Job_15', 'processing_time': 10, 'due_date': 49}
j20 = {'id': 'Job_19', 'processing_time': 10, 'due_date': 74}

# %%
j1 =  {'id': 'Job_9', 'processing_time': 1, 'due_date': 49}
j2 = {'id': 'Job_16', 'processing_time': 1, 'due_date': 24}
j3 = {'id': 'Job_12', 'processing_time': 2, 'due_date': 3}
j4 =  {'id': 'Job_2', 'processing_time': 3, 'due_date': 45}
j5 =  {'id': 'Job_4', 'processing_time': 3, 'due_date': 39}
j6 = {'id': 'Job_10', 'processing_time': 3, 'due_date': 28}
j7 = {'id': 'Job_18', 'processing_time': 3, 'due_date': 41}
j8 = {'id': 'Job_11', 'processing_time': 4, 'due_date': 46}
j9 =  {'id': 'Job_8', 'processing_time': 5, 'due_date': 48}
j10 = {'id': 'Job_13', 'processing_time': 5, 'due_date': 46}
j11 = {'id': 'Job_20', 'processing_time': 5, 'due_date': 48}
j12 =  {'id': 'Job_1', 'processing_time': 6, 'due_date': 26}
j13 = {'id': 'Job_17', 'processing_time': 6, 'due_date': 45}
j14 =  {'id': 'Job_6', 'processing_time': 7, 'due_date': 30}
j15 =  {'id': 'Job_3', 'processing_time': 8, 'due_date': 14}
j16 =  {'id': 'Job_5', 'processing_time': 9, 'due_date': 44}
j17 =  {'id': 'Job_7', 'processing_time': 9, 'due_date': 47}
j18 = {'id': 'Job_14', 'processing_time': 9, 'due_date': 18}
j19 = {'id': 'Job_15', 'processing_time': 10, 'due_date': 49}
j20 = {'id': 'Job_19', 'processing_time': 10, 'due_date': 74}

# %%
j1 = {'id': 'Job_15', 'processing_time': 10, 'due_date': 49}
j2 = {'id': 'Job_19', 'processing_time': 10, 'due_date': 74}
j3 =  {'id': 'Job_5', 'processing_time': 9, 'due_date': 44}
j4 =  {'id': 'Job_7', 'processing_time': 9, 'due_date': 47}
j5 = {'id': 'Job_14', 'processing_time': 9, 'due_date': 18}
j6 =  {'id': 'Job_3', 'processing_time': 8, 'due_date': 14}
j7 =  {'id': 'Job_6', 'processing_time': 7, 'due_date': 30}
j8 = {'id': 'Job_17', 'processing_time': 6, 'due_date': 45}
j9 =  {'id': 'Job_1', 'processing_time': 6, 'due_date': 26}
j10 =  {'id': 'Job_8', 'processing_time': 5, 'due_date': 48}
j11 = {'id': 'Job_13', 'processing_time': 5, 'due_date': 46}
j12 = {'id': 'Job_20', 'processing_time': 5, 'due_date': 48}
j13 = {'id': 'Job_11', 'processing_time': 4, 'due_date': 46}
j14 =  {'id': 'Job_2', 'processing_time': 3, 'due_date': 45}
j15 =  {'id': 'Job_4', 'processing_time': 3, 'due_date': 39}
j16 = {'id': 'Job_10', 'processing_time': 3, 'due_date': 28}
j17 = {'id': 'Job_18', 'processing_time': 3, 'due_date': 41}
j18 = {'id': 'Job_12', 'processing_time': 2, 'due_date': 3}
j19 =  {'id': 'Job_9', 'processing_time': 1, 'due_date': 49}
j20 = {'id': 'Job_16', 'processing_time': 1, 'due_date': 24}

# %% [markdown]
# #### Defining a jobs sequence using a list

# %%
default_sequence = [j1,j2,j3,j4,j5,j6,j7,j8,j9,j10,j11,j12,j13,j14,j15,j16,j17,j18,j19,j20]

# %%
list=[]
for i in range(20):
    list.append(default_sequence[i]['due_date'])
    
list
# Out:
# [3, 14, 18, 24, 26, 28, 30, 39, 41, 44, 45, 45, 46, 46, 47, 48, 48, 49, 49, 74]

# %%
list1= list

# %%
list1.sort()

list1
# Out:
# [3, 14, 18, 24, 26, 28, 30, 39, 41, 44, 45, 45, 46, 46, 47, 48, 48, 49, 49, 74]

# %% [markdown]
# #### Processing the schedule

# %%
def compute_schedule(sequence):
    schedule = copy.deepcopy(sequence) 
    t = 0
    for job in schedule:
        proc = job["processing_time"]
        job["start"] = t
        job["complete"] = t + proc
        #print(job["complete"])
        job["lateness"] = max(0, job["complete"] - job["due_date"])
        #print('lateness')
        #print(job["lateness"])
        if job["lateness"] > 0:
            job["late"] = 1
        else:
            job["late"] = 0
        t = t + proc
    return(schedule)

# %%
schedule = compute_schedule(default_sequence)
print(schedule)
# Out:
# [{'id': 'Job_12', 'processing_time': 2, 'due_date': 3, 'start': 0, 'complete': 2, 'lateness': 0, 'late': 0}, {'id': 'Job_3', 'processing_time': 8, 'due_date': 14, 'start': 2, 'complete': 10, 'lateness': 0, 'late': 0}, {'id': 'Job_14', 'processing_time': 9, 'due_date': 18, 'start': 10, 'complete': 19, 'lateness': 1, 'late': 1}, {'id': 'Job_16', 'processing_time': 1, 'due_date': 24, 'start': 19, 'complete': 20, 'lateness': 0, 'late': 0}, {'id': 'Job_1', 'processing_time': 6, 'due_date': 26, 'start': 20, 'complete': 26, 'lateness': 0, 'late': 0}, {'id': 'Job_10', 'processing_time': 3, 'due_date': 28, 'start': 26, 'complete': 29, 'lateness': 1, 'late': 1}, {'id': 'Job_6', 'processing_time': 7, 'due_date': 30, 'start': 29, 'complete': 36, 'lateness': 6, 'late': 1}, {'id': 'Job_4', 'processing_time': 3, 'due_date': 39, 'start': 36, 'complete': 39, 'lateness': 0, 'late': 0}, {'id': 'Job_18', 'processing_time': 3, 'due_date': 41, 'start': 39, 'complete': 42, 'lateness': 1, 'late': 1}, {'id':
# ...

# %% [markdown]
# #### Computing performance metrics

# %%
# long way 
def compute_num_jobs_late(schedule):
    num_jobs_late = 0
    for job in schedule:
        num_jobs_late = num_jobs_late + job["late"]
    return num_jobs_late

# %%
# short way using "list comprehension"
def compute_num_jobs_late(schedule):
    num_jobs_late = sum(job["late"] for job in schedule)
    return num_jobs_late

# %%
def compute_max_lateness(schedule):
    max_lateness = max(job["lateness"] for job in schedule)
    return max_lateness

# %%
def compute_sum_completion_times(schedule):
    sum_completion_times = sum(job["complete"] for job in schedule) 
    return sum_completion_times

# %% [markdown]
# #### Evaluating the default sequence

# %%
default_schedule = compute_schedule(default_sequence)

# %%
num_jobs_late = compute_num_jobs_late(default_schedule)
print("Using the default sequence, the number of jobs late is ", num_jobs_late)
# Out:
# Using the default sequence, the number of jobs late is  15

# %%
max_lateness = compute_max_lateness(default_schedule)
print("Using the default sequence, the maximum lateness is ", max_lateness)
# Out:
# Using the default sequence, the maximum lateness is  50

# %%
sum_completion_times = compute_sum_completion_times(default_schedule)
print("Using the default sequence, the sum of completion times ", sum_completion_times)
# Out:
# Using the default sequence, the sum of completion times  1068

# %% [markdown]
# #### Questions for discussion session

# %% [markdown]
# Q1) Can we write a function that minimizes max_lateness?

# %% [markdown]
# Q2) Can we write a function that minimizes sum_completion_times?

# %% [markdown]
# ### END
