# %% [markdown]
#  # Phase 1 - Ingestion and Cleaning
#
#  This notebook carries out the following steps
#    1. Ingest data downloaded from the LendingClub website
#    2. Choose columns to examine and prepare the data set
#    3. Visualizes single variable summaries
#    4. Removes outliers
#    5. Output a dataset ready for later analysis
#
#  Things for you to add
#  - Choose 3 to 5 variables and add them to the list of variables below
#  - Try visualizing the new variables and other pairs of variables
#
#  Prepare your presentation. Your presentation should contain at most 6 slides.
#  1. Begin by giving an overview of the project. What is the problem you wish to solve, what are the objectives? How will you evaluate the performance of the portfolio you provide? How will you measure success? What are the business KPIs?
#  2. What variables did you select for further inspection? Why do you think they will be useful? You may support any argument with a visualization.
#  3. List any insight you gained by looking at the data visualization or any other data analysis that you perform.
#  4. List 3-5 hypothesis about which variables will be important for analysis, and how they will affect the outcome.
#  5. State your conclusions. What is the main idea you wish to convey with the presentation? Do you think the data available will be useful to solve the problem?

# %%
import pandas as pd
import os
from sys import platform
import matplotlib.pyplot as plt
import datetime
import numpy as np
import pickle
import seaborn

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz
# You may have to install graphviz if you're not using Google Colab
from graphviz import Source
from sklearn.metrics import mean_squared_error

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.tree import export_graphviz
from graphviz import Source
from matplotlib import pyplot

# %%
def is_integer(x):
    '''
    This function returns True if x is an integer, and False otherwise
    '''
    try:
        return (int(x) == float(x))
    except:
        return False

# %% [markdown]
#  ## Parameters

# %%
#You can download the archived data for 2014 from the WayBack machine here: 
# https://web.archive.org/web/20160703081246/https://resources.lendingclub.com/LoanStats3c.csv.zip
# For the 2012-13 data, use https://web.archive.org/web/20160703081246/https://resources.lendingclub.com/LoanStats3b.csv.zip 
# Download both zip files and unzip them.
# Put both these unzipped files in the appropriate folder ("../data" below) before proceeding below.
# The data dictionary is here: https://web.archive.org/web/20200606105339/https://resources.lendingclub.com/LCDataDictionary.xlsx}
dir_data= "/Users/hrishikeshharishkumar/Documents/CMU Tepper - MSBA/Mini 1 - Fall 2023/Business Value through Integrative Analytics/Update 1 - Business and Data Understanding/Data1"

# %% [markdown]
#  ## Step 1 - Ingestion
#  Ingest the data files from both sets, perform consistency checks, and prepare one single file for each set

# %%
from typing import Dict, final
def ingest_files(directory: str) -> Dict:
    '''
    This function will ingest every file in the specified directory
    into a pandas dataframe. It will return a dictionary containing
    these dataframes, keyed by the file name.
    
    We assume the directory contains files directly downloaded from
    Lending Club, and *only* those files. Thus, we assume the files are zipped
    (pd.read_csv can read zipped files) and we assume the first line
    in each file needs to be skipped. 
    
    Note that this function will read and ingest more than one file and is
    convenient if you want to ingest data for more than one year at a time.
    
    Note that each file will be read *without* formatting
    '''
    
    # If the directory has no trailing slash, add one
    if directory[-1] != "/":
        directory = directory + "/"
    
    all_files = os.listdir(directory)
    output = {}
    
    print("Directory " + directory + " has " + str(len(all_files)) + " files:")
    for i in all_files:
        print("    Reading file " + i)
        output[i] = pd.read_csv(directory + i, dtype = str, skiprows = 1)
        
        # Some of the files have "summary" lines that, for example
        # read "Total number of loans number in Policy 1: ....."
        # To remove those lines, find any lines with non-integer IDs
        # and remove them
        invalid_rows = (output[i].id.apply( lambda x : is_integer(x) == False ))
        if invalid_rows.sum() > 0:
            print("        Found " + str(invalid_rows.sum()) + " invalid rows which were removed")
            output[i] = output[i][invalid_rows == False]
    
    return output

# %%
# Ingest the set of files we downloaded 
files_data = ingest_files(dir_data)
# Out:
# Directory /Users/hrishikeshharishkumar/Documents/CMU Tepper - MSBA/Mini 1 - Fall 2023/Business Value through Integrative Analytics/Update 1 - Business and Data Understanding/Data1/ has 1 files:
#     Reading file LoanStats3b.csv
#         Found 2 invalid rows which were removed

# %%
files_data.keys()
# Out:
# dict_keys(['LoanStats3b.csv'])

# %%
data_now = pd.concat(files_data.values()).reset_index(drop = True)
columns = list(data_now.columns)
columns
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_il_6m',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit']

# %%
print(data_now.isnull().sum())
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                         0
# tot_hi_cred_lim               27741
# total_bal_ex_mort              7495
# total_bc_limit                 7495
# total_il_high_credit_limit    27741
# Length: 111, dtype: int64

# %%
#data_now.isnull().sum().to_csv('test.csv')
data_now
# Out:
#               id member_id loan_amnt funded_amnt funded_amnt_inv        term  \
# 0       10129403  11981032      7550        7550            7550   36 months
# 1       10149342  12000897     27050       27050           27050   36 months
# 2       10159584  12011200      9750        9750            9750   36 months
# 3       10159498   1319523     12000       12000           12000   36 months
# 4       10129506  11981122     20800       20800           20800   36 months
# ...          ...       ...       ...         ...             ...         ...
# 188118   1062400   1294262     20500       20500           20500   36 months
# 188119   1059394   1291010     15000       15000           15000   36 months
# 188120   1059224   1290827     35000       35000           35000   36 months
# 188121   1058722   1290521     12000       12000           12000   36 months
# 188122   1058291   1289878     12000        7775            7775   60 months
#
#        int_rate installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0        16.24%      266.34     C        C5  ...                  0
# 1        10.99%      885.46     B        B2  ...                  0
# 2        13.98%      333.14     C        C1  ...                  0
# 3         6.62%      368.45     A        A2  ...                  0
# 4        13.53%      706.16     B        B5  ...                  0
# ...         ...         ...   ...       ...  ...                ...
# 188118   16.77%      728.54     D        D2  ...                NaN
# 188119   15.27%      521.97     C        C4  ...                NaN
# 188120   15.96%     1229.81     C        C5  ...                NaN
# 188121   16.29%      423.61     D        D1  ...                NaN
# 188122   15.27%      186.08     C        C4  ...                NaN
#
#        num_tl_op_past_12m pct_tl_nvr_dlq percent_bc_gt_75  \
# 0                       0            100              100
# 1                       1            100               25
# 2                       2            100             66.7
# 3                       2           95.5                0
# 4                       3           90.2               50
# ...                   ...            ...              ...
# 188118                NaN            NaN              NaN
# 188119                NaN            NaN              NaN
# 188120                NaN            NaN              NaN
# 188121                NaN            NaN              NaN
# 188122                NaN            NaN              NaN
#
#        pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 0                         0         0            8000              5759
# 1                         0         0          138554             70186
# 2                         0         0           21314             14123
# 3                         0         0          333044             42603
# 4                         0         0           43100             23473
# ...                     ...       ...             ...               ...
# 188118                    0         0             NaN               NaN
# 188119                    0         0             NaN               NaN
# 188120                    0         0             NaN               NaN
# 188121                    0         0             NaN               NaN
# 188122                    0         0             NaN               NaN
#
#        total_bc_limit total_il_high_credit_limit
# 0                4000                          0
# 1               35700                      33054
# 2                7200                       6214
# 3               52600                      42769
# 4               15000                          0
# ...               ...                        ...
# 188118            NaN                        NaN
# 188119            NaN                        NaN
# 188120            NaN                        NaN
# 188121            NaN                        NaN
# 188122            NaN                        NaN
#
# [188123 rows x 111 columns]

# %% [markdown]
#  ## Step 2 - Choose Columns and Prepare Dataset

# %%
# Identify the columns we'll be keeping from the dataset
# New Columns to be added:
# bc_util: Ratio of total current balance to high credit/credit limit for all bankcard accounts.
# inq_last_6mths: The number of inquiries in past 6 months (excluding auto and mortgage inquiries)
# mths_since_last_delinq: The number of months since the borrower's last delinquency.-- removed because of missing data
# pct_tl_nvr_dlq: Percent of trades never delinquent
# total_acc: The total number of credit lines currently in the borrower's credit file
# chargeoff_within_12_mths - Number of charge-offs within 12 months


cols_to_pick = ['id','loan_amnt','funded_amnt','term','int_rate',
                 'installment','grade','emp_length', 'home_ownership',
                 'annual_inc','verification_status','issue_d',
                 'loan_status','purpose','dti', 'delinq_2yrs',
                 'earliest_cr_line','open_acc','pub_rec',
                 'revol_bal','revol_util', 'total_pymnt',
                  'recoveries',
               'bc_util','inq_last_6mths', 'pct_tl_nvr_dlq','total_acc','chargeoff_within_12_mths','funded_amnt_inv',
               'sub_grade','emp_title','pymnt_plan','addr_state','mths_since_last_delinq',
               'initial_list_status','out_prncp','out_prncp_inv','collections_12_mths_ex_med',
               'application_type','tot_cur_bal','pub_rec_bankruptcies','total_bal_ex_mort']

# Identify the type of each of these column
float_cols = ['loan_amnt', 'funded_amnt', 'installment', 'annual_inc',
                     'dti', 'revol_bal', 'delinq_2yrs', 'open_acc', 'pub_rec',
                                'total_pymnt', 'recoveries','bc_util','inq_last_6mths','chargeoff_within_12_mths',
             'pct_tl_nvr_dlq','total_acc','funded_amnt_inv','inq_last_6mths','mths_since_last_delinq','out_prncp',
              'out_prncp_inv','collections_12_mths_ex_med','tot_cur_bal','pub_rec_bankruptcies','total_bal_ex_mort']

cat_cols = ['term', 'grade', 'emp_length', 'home_ownership',
                    'verification_status', 'loan_status', 'purpose','sub_grade','emp_title','pymnt_plan',
           'addr_state','initial_list_status','application_type']
perc_cols = ['int_rate', 'revol_util']
date_cols = ['issue_d', 'earliest_cr_line']

# Ensure that we have types for every column
assert set(cols_to_pick) - set(float_cols) - set(cat_cols) - set(perc_cols) - set(date_cols) == set(["id"])

# %%
# Keep only the columns of interest
final_data = data_now[cols_to_pick].copy()

# %%
print("Starting with " + str(len(final_data)) + " rows")
# Out:
# Starting with 188123 rows

# %%
final_data.shape
# Out:
# (188123, 42)

# %%
duplicate_rows_df = final_data[final_data.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 42)

# %%
print(final_data.isnull().sum())
# Out:
# id                                 0
# loan_amnt                          0
# funded_amnt                        0
# term                               0
# int_rate                           0
# installment                        0
# grade                              0
# emp_length                      7877
# home_ownership                     0
# annual_inc                         0
# verification_status                0
# issue_d                            0
# loan_status                        0
# purpose                            0
# dti                                0
# delinq_2yrs                        0
# earliest_cr_line                   0
# open_acc                           0
# pub_rec                            0
# revol_bal                          0
# revol_util                       125
# total_pymnt                        0
# recoveries                         0
# bc_util                         9111
# inq_last_6mths                     0
# pct_tl_nvr_dlq                 27894
# total_acc                          0
# chargeoff_within_12_mths           0
# funded_amnt_inv                    0
# sub_grade                          0
# emp_title                      11726
# pymnt_plan                         0
# addr_state                         0
# mths_since_last_delinq        107544
# initial_list_status                0
# out_prncp                          0
# out_prncp_inv                      0
# collections_12_mths_ex_med         0
# application_type                   0
# tot_cur_bal                    27741
# pub_rec_bankruptcies               0
# total_bal_ex_mort               7495
# dtype: int64

# %%
nan_mean = final_data.isna().mean()
nan_mean = nan_mean[nan_mean != 0].sort_values()
nan_mean
# Out:
# revol_util                0.000664
# total_bal_ex_mort         0.039841
# emp_length                0.041872
# bc_util                   0.048431
# emp_title                 0.062332
# tot_cur_bal               0.147462
# pct_tl_nvr_dlq            0.148275
# mths_since_last_delinq    0.571669
# dtype: float64

# %%
num_feat = final_data.select_dtypes('number').columns.values
final_data[num_feat].nunique().sort_values()
# Out:
# Series([], dtype: float64)

# %%
from itertools import combinations
from scipy.stats import pearsonr, chi2_contingency
num_feat = final_data.select_dtypes('number').columns.values
comb_num_feat = np.array(list(combinations(num_feat, 2)))
corr_num_feat = np.array([])
for comb in comb_num_feat:
    corr = pearsonr(final_data[comb[0]], final_data[comb[1]])[0]
    corr_num_feat = np.append(corr_num_feat, corr)

# %%
high_corr_num = comb_num_feat[np.abs(corr_num_feat) >= 0.9]
high_corr_num
# Out:
# array([], dtype=float64)

# %% [markdown]
#  # To do (A)
#
#  Choose 3 to 5 variables and add them to the list of variables below
#
#  You should consult the data description (excel) file you downloaded to understand the definition of various available columns
#
#  TIP: If you added new variables, be sure to clean them as we just did for the default variables.
#
#  You will have to add them to the group of the right type of variables (e.g. percentage, date, categorical)

# %% [markdown]
#  ### Typecast the columns

# %%
for i in float_cols:
    final_data[i] = final_data[i].astype(float)
    
def clean_perc(x):
    if pd.isnull(x):
        return np.nan
    else:
        return float(x.rstrip()[:-1])
for i in perc_cols:
    final_data[i] = final_data[i].apply( clean_perc )
    
def clean_date(x):
    if pd.isnull(x):
        return None
    else:
        return datetime.datetime.strptime( x, "%b-%Y").date()
for i in date_cols:
    final_data[i] = final_data[i].apply( clean_date )
    
for i in cat_cols:
    final_data.loc[final_data[i].isnull(), i] = None

# %%
final_data.head()
# Out:
#          id  loan_amnt  funded_amnt        term  int_rate  installment grade  \
# 0  10129403     7550.0       7550.0   36 months     16.24       266.34     C
# 1  10149342    27050.0      27050.0   36 months     10.99       885.46     B
# 2  10159584     9750.0       9750.0   36 months     13.98       333.14     C
# 3  10159498    12000.0      12000.0   36 months      6.62       368.45     A
# 4  10129506    20800.0      20800.0   36 months     13.53       706.16     B
#
#   emp_length home_ownership  annual_inc  ... addr_state  \
# 0    3 years           RENT     28000.0  ...         CA
# 1  10+ years            OWN     55000.0  ...         MI
# 2     1 year           RENT     26000.0  ...         CA
# 3  10+ years       MORTGAGE    105000.0  ...         CT
# 4  10+ years           RENT     81500.0  ...         NY
#
#   mths_since_last_delinq initial_list_status out_prncp  out_prncp_inv  \
# 0                    NaN                   w   1767.05        1767.05
# 1                    NaN                   w   5977.03        5977.03
# 2                    NaN                   f   2227.23        2227.23
# 3                   43.0                   w   2522.93        2522.93
# 4                   64.0                   f      0.00           0.00
#
#    collections_12_mths_ex_med application_type  tot_cur_bal  \
# 0                         0.0       INDIVIDUAL       5759.0
# 1                         0.0       INDIVIDUAL     114834.0
# 2                         0.0       INDIVIDUAL      14123.0
# 3                         0.0       INDIVIDUAL     267646.0
# 4                         0.0       INDIVIDUAL      23473.0
#
#    pub_rec_bankruptcies  total_bal_ex_mort
# 0                   0.0             5759.0
# 1                   0.0            70186.0
# 2                   0.0            14123.0
# 3                   0.0            42603.0
# 4                   0.0            23473.0
#
# [5 rows x 42 columns]

# %% [markdown]
#  ## Step 4 - Handle outliers

# %%
len(final_data)
# Out:
# 188123

# %%
# There are quite a few outliers, but the two most obvious
# ones to remove are in annual_inc, revol_bal Remove these.
n_rows = len(final_data)
final_data = final_data[final_data.annual_inc < 1000000]
final_data = final_data[final_data.revol_bal < 400000]
final_data = final_data[final_data.dti < 200]

final_data = final_data[final_data.tot_cur_bal < 1000000]
final_data = final_data[final_data.pct_tl_nvr_dlq > 80]
final_data = final_data[final_data.total_acc < 60]

print("Removed " + str(n_rows - len(final_data)) + " rows")
# Out:
# Removed 37763 rows

# %%
len(final_data)
# Out:
# 150360

# %%
# Remove all loans that are too recent to have been paid off or
# defaulted
n_rows = len(final_data)
final_data = final_data[final_data.loan_status.isin(['Fully Paid','Charged Off','Default'])]
print("Removed " + str(n_rows - len(final_data)) + " rows")
# Out:
# Removed 38300 rows

# %%
len(final_data)
# Out:
# 112060

# %%
# Only include loans issued since 2009
n_rows = len(final_data)
final_data = final_data[final_data.issue_d >= datetime.date(2009, 1, 1)]
print("Removed " + str(n_rows - len(final_data)) + " rows")
# Out:
# Removed 0 rows

# %% [markdown]
#  ### Drop null values

# %%
# Deal with null values. We allow categorical variables to be null
# OTHER than grade, which is a particularly important categorical.
# All non-categorical variables must be non-null, and we drop
# rows that do not meet this requirement
required_cols = set(cols_to_pick) - set(cat_cols) - set(["id"])
required_cols.add("grade")

n_rows = len(final_data)
final_data.dropna(subset = required_cols ,inplace=True)
print("Removed " + str(n_rows - len(final_data)) + " rows")
# Out:
# Removed 66454 rows

# %%
len(final_data)
# Out:
# 45606

# %%
# Some of the columns selected will not be used directly in the model,
# but will be used to generate other features.
#
# Create variables specifying the features that will be used

# All categorical columns other than "loan_status" will be used as
# discrete features
discrete_features = list(set(cat_cols) - set(["loan_status"]))

# All numeric columns will be used as continuous features
continuous_features = list(float_cols + perc_cols)

# %% [markdown]
#  ## Step 5 - Save a Pickle

# %%
# Remove the total_pymnt from the list of continuous features; this
# variable is highly predictive of the outcome but is not known at
# the time the loan is issued
continuous_features = [i for i in continuous_features if i not in ["total_pymnt", "recoveries"]]

# %%
# Define the output path for the pickle
pickle_file = "/".join(['.', "PickleData", "clean_data.pickle"])
os.makedirs(os.path.dirname(pickle_file), exist_ok=True)
pickle.dump( [final_data, discrete_features, continuous_features], open(pickle_file, "wb") )

# %%
final_data.head()
# Out:
#           id  loan_amnt  funded_amnt        term  int_rate  installment grade  \
# 4   10129506    20800.0      20800.0   36 months     13.53       706.16     B
# 6   10179520     3000.0       3000.0   36 months     12.85       100.87     B
# 7   10139658    12000.0      12000.0   36 months     13.53       407.40     B
# 30  10089642     7200.0       7200.0   36 months     10.99       235.69     B
# 31  10109669    20000.0      20000.0   36 months     13.98       683.36     C
#
#    emp_length home_ownership  annual_inc  ... addr_state  \
# 4   10+ years           RENT     81500.0  ...         NY
# 6   10+ years           RENT     25000.0  ...         FL
# 7   10+ years           RENT     40000.0  ...         NM
# 30    4 years            OWN     70000.0  ...         CA
# 31  10+ years       MORTGAGE     80000.0  ...         CA
#
#    mths_since_last_delinq initial_list_status out_prncp  out_prncp_inv  \
# 4                    64.0                   f       0.0            0.0
# 6                    58.0                   f       0.0            0.0
# 7                    53.0                   w       0.0            0.0
# 30                   59.0                   f       0.0            0.0
# 31                    8.0                   f       0.0            0.0
#
#     collections_12_mths_ex_med application_type  tot_cur_bal  \
# 4                          0.0       INDIVIDUAL      23473.0
# 6                          0.0       INDIVIDUAL      19530.0
# 7                          0.0       INDIVIDUAL      13605.0
# 30                         0.0       INDIVIDUAL      45598.0
# 31                         0.0       INDIVIDUAL      16852.0
#
#     pub_rec_bankruptcies  total_bal_ex_mort
# 4                    0.0            23473.0
# 6                    2.0            19530.0
# 7                    0.0            13605.0
# 30                   1.0            45598.0
# 31                   1.0            16852.0
#
# [5 rows x 42 columns]

# %% [markdown]
#  ## Read from Pickle if Saved
#  Read data from saved pickle files

# %%
### Read the data and features from the pickle
final_data, discrete_features, continuous_features = pickle.load( open( "./PickleData/clean_data.pickle", "rb" ) )
#final_data, discrete_features, continuous_features = pickle.load( open( "./PickleData/201213clean_data.pickle", "rb" ) )

# %%
len(final_data)
# Out:
# 45606

# %%
final_data['loan_status']
# Out:
# 4         Fully Paid
# 6         Fully Paid
# 7         Fully Paid
# 30        Fully Paid
# 31        Fully Paid
#              ...
# 160523    Fully Paid
# 160532    Fully Paid
# 160533    Fully Paid
# 160540    Fully Paid
# 160545    Fully Paid
# Name: loan_status, Length: 45606, dtype: object

# %%
final_data['loan_status'].value_counts()
# Out:
# Fully Paid     37630
# Charged Off     7956
# Default           20
# Name: loan_status, dtype: int64

# %%
final_data_new = final_data.copy()

# %%
final_data_new
# Out:
#               id  loan_amnt  funded_amnt        term  int_rate  installment  \
# 4       10129506    20800.0      20800.0   36 months     13.53       706.16
# 6       10179520     3000.0       3000.0   36 months     12.85       100.87
# 7       10139658    12000.0      12000.0   36 months     13.53       407.40
# 30      10089642     7200.0       7200.0   36 months     10.99       235.69
# 31      10109669    20000.0      20000.0   36 months     13.98       683.36
# ...          ...        ...          ...         ...       ...          ...
# 160523   1471874    16050.0      16050.0   36 months     17.27       574.39
# 160532   1471784     6500.0       6500.0   36 months     10.16       210.23
# 160533   1465551    35000.0      35000.0   36 months     10.16      1131.99
# 160540   1471798    19125.0      19125.0   36 months     15.31       665.89
# 160545   1471439    11100.0      11100.0   36 months     18.49       404.03
#
#        grade emp_length home_ownership  annual_inc  ... addr_state  \
# 4          B  10+ years           RENT     81500.0  ...         NY
# 6          B  10+ years           RENT     25000.0  ...         FL
# 7          B  10+ years           RENT     40000.0  ...         NM
# 30         B    4 years            OWN     70000.0  ...         CA
# 31         C  10+ years       MORTGAGE     80000.0  ...         CA
# ...      ...        ...            ...         ...  ...        ...
# 160523     C     1 year           RENT     41000.0  ...         FL
# 160532     B     1 year       MORTGAGE     45000.0  ...         FL
# 160533     B  10+ years           RENT    180000.0  ...         NY
# 160540     C  10+ years           RENT     48000.0  ...         FL
# 160545     D    6 years       MORTGAGE     77000.0  ...         PA
#
#        mths_since_last_delinq initial_list_status out_prncp  out_prncp_inv  \
# 4                        64.0                   f       0.0            0.0
# 6                        58.0                   f       0.0            0.0
# 7                        53.0                   w       0.0            0.0
# 30                       59.0                   f       0.0            0.0
# 31                        8.0                   f       0.0            0.0
# ...                       ...                 ...       ...            ...
# 160523                   16.0                   f       0.0            0.0
# 160532                   31.0                   f       0.0            0.0
# 160533                   67.0                   f       0.0            0.0
# 160540                   54.0                   f       0.0            0.0
# 160545                   22.0                   f       0.0            0.0
#
#         collections_12_mths_ex_med application_type  tot_cur_bal  \
# 4                              0.0       INDIVIDUAL      23473.0
# 6                              0.0       INDIVIDUAL      19530.0
# 7                              0.0       INDIVIDUAL      13605.0
# 30                             0.0       INDIVIDUAL      45598.0
# 31                             0.0       INDIVIDUAL      16852.0
# ...                            ...              ...          ...
# 160523                         0.0       INDIVIDUAL      43866.0
# 160532                         0.0       INDIVIDUAL     205051.0
# 160533                         0.0       INDIVIDUAL      93166.0
# 160540                         0.0       INDIVIDUAL      20985.0
# 160545                         0.0       INDIVIDUAL     395050.0
#
#         pub_rec_bankruptcies  total_bal_ex_mort
# 4                        0.0            23473.0
# 6                        2.0            19530.0
# 7                        0.0            13605.0
# 30                       1.0            45598.0
# 31                       1.0            16852.0
# ...                      ...                ...
# 160523                   0.0            43866.0
# 160532                   0.0            65466.0
# 160533                   0.0            93166.0
# 160540                   0.0            20985.0
# 160545                   0.0           132718.0
#
# [45606 rows x 42 columns]

# %% [markdown]
# ## Data Manipulation

# %%
#final_data = final_data_new.copy()

# %%
final_data
# Out:
#               id  loan_amnt  funded_amnt        term  int_rate  installment  \
# 4       10129506    20800.0      20800.0   36 months     13.53       706.16
# 6       10179520     3000.0       3000.0   36 months     12.85       100.87
# 7       10139658    12000.0      12000.0   36 months     13.53       407.40
# 30      10089642     7200.0       7200.0   36 months     10.99       235.69
# 31      10109669    20000.0      20000.0   36 months     13.98       683.36
# ...          ...        ...          ...         ...       ...          ...
# 160523   1471874    16050.0      16050.0   36 months     17.27       574.39
# 160532   1471784     6500.0       6500.0   36 months     10.16       210.23
# 160533   1465551    35000.0      35000.0   36 months     10.16      1131.99
# 160540   1471798    19125.0      19125.0   36 months     15.31       665.89
# 160545   1471439    11100.0      11100.0   36 months     18.49       404.03
#
#        grade emp_length home_ownership  annual_inc  ... addr_state  \
# 4          B  10+ years           RENT     81500.0  ...         NY
# 6          B  10+ years           RENT     25000.0  ...         FL
# 7          B  10+ years           RENT     40000.0  ...         NM
# 30         B    4 years            OWN     70000.0  ...         CA
# 31         C  10+ years       MORTGAGE     80000.0  ...         CA
# ...      ...        ...            ...         ...  ...        ...
# 160523     C     1 year           RENT     41000.0  ...         FL
# 160532     B     1 year       MORTGAGE     45000.0  ...         FL
# 160533     B  10+ years           RENT    180000.0  ...         NY
# 160540     C  10+ years           RENT     48000.0  ...         FL
# 160545     D    6 years       MORTGAGE     77000.0  ...         PA
#
#        mths_since_last_delinq initial_list_status out_prncp  out_prncp_inv  \
# 4                        64.0                   f       0.0            0.0
# 6                        58.0                   f       0.0            0.0
# 7                        53.0                   w       0.0            0.0
# 30                       59.0                   f       0.0            0.0
# 31                        8.0                   f       0.0            0.0
# ...                       ...                 ...       ...            ...
# 160523                   16.0                   f       0.0            0.0
# 160532                   31.0                   f       0.0            0.0
# 160533                   67.0                   f       0.0            0.0
# 160540                   54.0                   f       0.0            0.0
# 160545                   22.0                   f       0.0            0.0
#
#         collections_12_mths_ex_med application_type  tot_cur_bal  \
# 4                              0.0       INDIVIDUAL      23473.0
# 6                              0.0       INDIVIDUAL      19530.0
# 7                              0.0       INDIVIDUAL      13605.0
# 30                             0.0       INDIVIDUAL      45598.0
# 31                             0.0       INDIVIDUAL      16852.0
# ...                            ...              ...          ...
# 160523                         0.0       INDIVIDUAL      43866.0
# 160532                         0.0       INDIVIDUAL     205051.0
# 160533                         0.0       INDIVIDUAL      93166.0
# 160540                         0.0       INDIVIDUAL      20985.0
# 160545                         0.0       INDIVIDUAL     395050.0
#
#         pub_rec_bankruptcies  total_bal_ex_mort
# 4                        0.0            23473.0
# 6                        2.0            19530.0
# 7                        0.0            13605.0
# 30                       1.0            45598.0
# 31                       1.0            16852.0
# ...                      ...                ...
# 160523                   0.0            43866.0
# 160532                   0.0            65466.0
# 160533                   0.0            93166.0
# 160540                   0.0            20985.0
# 160545                   0.0           132718.0
#
# [45606 rows x 42 columns]

# %%
final_data['Default'] = final_data['loan_status'].apply(lambda x: 0 if x in ['Fully Paid'] else 1)

# %%
final_data.loc[final_data['term'].str.contains('36'), 'term_new'] = 36
final_data.loc[final_data['term'].str.contains('60'), 'term_new'] = 60
#df.loc[df['Activity'].str.contains('conference'), 'Activity_2'] = 'conference'

# %%
final_data
# Out:
#               id  loan_amnt  funded_amnt        term  int_rate  installment  \
# 4       10129506    20800.0      20800.0   36 months     13.53       706.16
# 6       10179520     3000.0       3000.0   36 months     12.85       100.87
# 7       10139658    12000.0      12000.0   36 months     13.53       407.40
# 30      10089642     7200.0       7200.0   36 months     10.99       235.69
# 31      10109669    20000.0      20000.0   36 months     13.98       683.36
# ...          ...        ...          ...         ...       ...          ...
# 160523   1471874    16050.0      16050.0   36 months     17.27       574.39
# 160532   1471784     6500.0       6500.0   36 months     10.16       210.23
# 160533   1465551    35000.0      35000.0   36 months     10.16      1131.99
# 160540   1471798    19125.0      19125.0   36 months     15.31       665.89
# 160545   1471439    11100.0      11100.0   36 months     18.49       404.03
#
#        grade emp_length home_ownership  annual_inc  ... initial_list_status  \
# 4          B  10+ years           RENT     81500.0  ...                   f
# 6          B  10+ years           RENT     25000.0  ...                   f
# 7          B  10+ years           RENT     40000.0  ...                   w
# 30         B    4 years            OWN     70000.0  ...                   f
# 31         C  10+ years       MORTGAGE     80000.0  ...                   f
# ...      ...        ...            ...         ...  ...                 ...
# 160523     C     1 year           RENT     41000.0  ...                   f
# 160532     B     1 year       MORTGAGE     45000.0  ...                   f
# 160533     B  10+ years           RENT    180000.0  ...                   f
# 160540     C  10+ years           RENT     48000.0  ...                   f
# 160545     D    6 years       MORTGAGE     77000.0  ...                   f
#
#        out_prncp out_prncp_inv collections_12_mths_ex_med  application_type  \
# 4            0.0           0.0                        0.0        INDIVIDUAL
# 6            0.0           0.0                        0.0        INDIVIDUAL
# 7            0.0           0.0                        0.0        INDIVIDUAL
# 30           0.0           0.0                        0.0        INDIVIDUAL
# 31           0.0           0.0                        0.0        INDIVIDUAL
# ...          ...           ...                        ...               ...
# 160523       0.0           0.0                        0.0        INDIVIDUAL
# 160532       0.0           0.0                        0.0        INDIVIDUAL
# 160533       0.0           0.0                        0.0        INDIVIDUAL
# 160540       0.0           0.0                        0.0        INDIVIDUAL
# 160545       0.0           0.0                        0.0        INDIVIDUAL
#
#         tot_cur_bal pub_rec_bankruptcies  total_bal_ex_mort  Default  term_new
# 4           23473.0                  0.0            23473.0        0      36.0
# 6           19530.0                  2.0            19530.0        0      36.0
# 7           13605.0                  0.0            13605.0        0      36.0
# 30          45598.0                  1.0            45598.0        0      36.0
# 31          16852.0                  1.0            16852.0        0      36.0
# ...             ...                  ...                ...      ...       ...
# 160523      43866.0                  0.0            43866.0        0      36.0
# 160532     205051.0                  0.0            65466.0        0      36.0
# 160533      93166.0                  0.0            93166.0        0      36.0
# 160540      20985.0                  0.0            20985.0        0      36.0
# 160545     395050.0                  0.0           132718.0        0      36.0
#
# [45606 rows x 44 columns]

# %% [markdown]
# ## One Hot Encoding

# %%
df_onehot1 = pd.get_dummies(final_data['grade'])

# %%
final_data = pd.concat([final_data, df_onehot1], axis=1)

# %%
df_onehot1 = pd.get_dummies(final_data['home_ownership'])

# %%
final_data = pd.concat([final_data, df_onehot1], axis=1)

# %%
df_onehot1 = pd.get_dummies(final_data['verification_status'])

# %%
final_data = pd.concat([final_data, df_onehot1], axis=1)

# %%
df_onehot1 = pd.get_dummies(final_data['initial_list_status'])

# %%
final_data = pd.concat([final_data, df_onehot1], axis=1)

# %%
final_data = final_data.drop(['grade','home_ownership','loan_status','verification_status','id','term'], axis=1, errors='ignore')


# ,'initial_list_status', 'subgrade'

# %% [markdown]
# ## Emp Length

# %%
final_data['emp_length_new'] = final_data['emp_length'].apply(lambda x: "experienced" if x in ['10+ years'] else "less experienced")

# %%
final_data = final_data.drop(['earliest_cr_line','emp_length','issue_d','purpose','emp_title','pymnt_plan','addr_state','application_type'], axis=1, errors='ignore')

# %%
df_onehot1 = pd.get_dummies(final_data['emp_length_new'])

# %%
final_data = pd.concat([final_data, df_onehot1], axis=1)

# %%
final_data = final_data.drop(['emp_length_new'], axis=1, errors='ignore')

# %%
df_onehot1 = pd.get_dummies(final_data['sub_grade'])

# %%
final_data = pd.concat([final_data, df_onehot1], axis=1)

# %%
final_data = final_data.drop(['sub_grade'], axis=1, errors='ignore')

# %%
final_data['init_list_status'] = final_data['initial_list_status'].apply(lambda x: 0 if x == 'w' else 1)

# %%
final_data = final_data.drop(['initial_list_status'], axis=1, errors='ignore')

# %%
final_data
# Out:
#         loan_amnt  funded_amnt  int_rate  installment  annual_inc    dti  \
# 4         20800.0      20800.0     13.53       706.16     81500.0  16.73
# 6          3000.0       3000.0     12.85       100.87     25000.0  24.68
# 7         12000.0      12000.0     13.53       407.40     40000.0  16.94
# 30         7200.0       7200.0     10.99       235.69     70000.0  19.20
# 31        20000.0      20000.0     13.98       683.36     80000.0  16.70
# ...           ...          ...       ...          ...         ...    ...
# 160523    16050.0      16050.0     17.27       574.39     41000.0  19.20
# 160532     6500.0       6500.0     10.16       210.23     45000.0  26.00
# 160533    35000.0      35000.0     10.16      1131.99    180000.0  23.71
# 160540    19125.0      19125.0     15.31       665.89     48000.0  14.94
# 160545    11100.0      11100.0     18.49       404.03     77000.0  34.33
#
#         delinq_2yrs  open_acc  pub_rec  revol_bal  ...  F2  F3  F4  F5  G1  \
# 4               0.0      29.0      0.0    23473.0  ...   0   0   0   0   0
# 6               0.0       5.0      2.0     2875.0  ...   0   0   0   0   0
# 7               0.0       7.0      2.0     5572.0  ...   0   0   0   0   0
# 30              0.0      14.0      1.0     3479.0  ...   0   0   0   0   0
# 31              1.0      10.0      1.0    12948.0  ...   0   0   0   0   0
# ...             ...       ...      ...        ...  ...  ..  ..  ..  ..  ..
# 160523          1.0      13.0      0.0    22267.0  ...   0   0   0   0   0
# 160532          0.0      15.0      0.0     1258.0  ...   0   0   0   0   0
# 160533          0.0      12.0      0.0    10187.0  ...   0   0   0   0   0
# 160540          0.0      17.0      0.0    20985.0  ...   0   0   0   0   0
# 160545          2.0      21.0      0.0    26154.0  ...   0   0   0   0   0
#
#         G2  G3  G4  G5  init_list_status
# 4        0   0   0   0                 1
# 6        0   0   0   0                 1
# 7        0   0   0   0                 0
# 30       0   0   0   0                 1
# 31       0   0   0   0                 1
# ...     ..  ..  ..  ..               ...
# 160523   0   0   0   0                 1
# 160532   0   0   0   0                 1
# 160533   0   0   0   0                 1
# 160540   0   0   0   0                 1
# 160545   0   0   0   0                 1
#
# [45606 rows x 83 columns]

# %% [markdown]
# ## Train Test Split

# %%
final_data
# Out:
#         loan_amnt  funded_amnt  int_rate  installment  annual_inc    dti  \
# 4         20800.0      20800.0     13.53       706.16     81500.0  16.73
# 6          3000.0       3000.0     12.85       100.87     25000.0  24.68
# 7         12000.0      12000.0     13.53       407.40     40000.0  16.94
# 30         7200.0       7200.0     10.99       235.69     70000.0  19.20
# 31        20000.0      20000.0     13.98       683.36     80000.0  16.70
# ...           ...          ...       ...          ...         ...    ...
# 160523    16050.0      16050.0     17.27       574.39     41000.0  19.20
# 160532     6500.0       6500.0     10.16       210.23     45000.0  26.00
# 160533    35000.0      35000.0     10.16      1131.99    180000.0  23.71
# 160540    19125.0      19125.0     15.31       665.89     48000.0  14.94
# 160545    11100.0      11100.0     18.49       404.03     77000.0  34.33
#
#         delinq_2yrs  open_acc  pub_rec  revol_bal  ...  F2  F3  F4  F5  G1  \
# 4               0.0      29.0      0.0    23473.0  ...   0   0   0   0   0
# 6               0.0       5.0      2.0     2875.0  ...   0   0   0   0   0
# 7               0.0       7.0      2.0     5572.0  ...   0   0   0   0   0
# 30              0.0      14.0      1.0     3479.0  ...   0   0   0   0   0
# 31              1.0      10.0      1.0    12948.0  ...   0   0   0   0   0
# ...             ...       ...      ...        ...  ...  ..  ..  ..  ..  ..
# 160523          1.0      13.0      0.0    22267.0  ...   0   0   0   0   0
# 160532          0.0      15.0      0.0     1258.0  ...   0   0   0   0   0
# 160533          0.0      12.0      0.0    10187.0  ...   0   0   0   0   0
# 160540          0.0      17.0      0.0    20985.0  ...   0   0   0   0   0
# 160545          2.0      21.0      0.0    26154.0  ...   0   0   0   0   0
#
#         G2  G3  G4  G5  init_list_status
# 4        0   0   0   0                 1
# 6        0   0   0   0                 1
# 7        0   0   0   0                 0
# 30       0   0   0   0                 1
# 31       0   0   0   0                 1
# ...     ..  ..  ..  ..               ...
# 160523   0   0   0   0                 1
# 160532   0   0   0   0                 1
# 160533   0   0   0   0                 1
# 160540   0   0   0   0                 1
# 160545   0   0   0   0                 1
#
# [45606 rows x 83 columns]

# %%
y = final_data["Default"]

# %%
X = final_data.drop("Default", axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=886)

# %%
rf_mod = RandomForestClassifier(n_estimators=1000,max_features="sqrt", random_state=886)

# %%
rf_mod.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=886)

# %%
importances = rf_mod.feature_importances_
sorted_indices = np.argsort(importances)[::-1]
 
feat_labels = X_train.columns[0:]
 
for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 50,
                            feat_labels[sorted_indices[f]],
                            importances[sorted_indices[f]]))
# Out:
#  1) recoveries                                         0.420852
#  2) total_pymnt                                        0.219082
#  3) funded_amnt_inv                                    0.037930
#  4) funded_amnt                                        0.037369
#  5) installment                                        0.036782
#  6) loan_amnt                                          0.036275
#  7) int_rate                                           0.016558
#  8) annual_inc                                         0.014269
#  9) dti                                                0.014093
# 10) revol_bal                                          0.013187
# 11) tot_cur_bal                                        0.012849
# 12) total_bal_ex_mort                                  0.012284
# 13) bc_util                                            0.012085
# 14) revol_util                                         0.011959
# 15) term_new                                           0.011706
# 16) mths_since_last_delinq                             0.010826
# 17) total_acc                                          0.009806
# 18) pct_tl_nvr_dlq                                     0.008901
# 19) open_acc                                           0.008794
# 20) inq_last_6mths                                     0.004387
# 21) delinq_2yrs                                        0.003041
# 22) B                                                  0.002586
# 23) E                                                  0.002206
# 24) A                                                  0.002153
# 25) F                                                  0.002012
# 26) Not Verified                                       0.001903
# 27) Verified                                           0.001878
# 28) pub_rec                                            0.001729
# 29) less experienced                                   0.001688
# 30) RENT                                               0.001667
# 31) experienced                                        0.001659
# 32) MORTGAGE                                           0.001651
# 33) Source Verified                                    0.001447
# 34) w                                                  0.001339
# 35) f                                                  0.001325
# 36) init_list_status                                   0.001303
# 37) D                                                  0.001271
# 38) pub_rec_bankruptcies                               0.001199
# 39) C                                                  0.001142
# 40) OWN                                                0.001116
# 41) out_prncp_inv                                      0.001050
# 42) out_prncp                                          0.001048
# 43) C4                                                 0.000683
# 44) C5                                                 0.000633
# 45) C3                                                 0.000611
# 46) C2                                                 0.000609
# 47) B4                                                 0.000597
# 48) D1                                                 0.000595
# 49) B3                                                 0.000522
# 50) D4                                                 0.000519
# 51) D3                                                 0.000518
# 52) D2                                                 0.000498
# 53) B2                                                 0.000494
# 54) E2                                                 0.000472
# 55) C1                                                 0.000466
# 56) D5                                                 0.000460
# 57) B5                                                 0.000442
# 58) A5                                                 0.000425
# 59) collections_12_mths_ex_med                         0.000399
# 60) B1                                                 0.000396
# 61) E5                                                 0.000389
# 62) F5                                                 0.000361
# 63) E3                                                 0.000345
# 64) chargeoff_within_12_mths                           0.000330
# 65) E1                                                 0.000326
# 66) E4                                                 0.000308
# 67) F2                                                 0.000275
# 68) G                                                  0.000248
# 69) F4                                                 0.000223
# 70) F1                                                 0.000222
# 71) G1                                                 0.000221
# 72) F3                                                 0.000211
# 73) A4                                                 0.000191
# 74) A3                                                 0.000145
# 75) A2                                                 0.000120
# 76) NONE                                               0.000096
# 77) G3                                                 0.000079
# 78) A1                                                 0.000050
# 79) G5                                                 0.000037
# 80) G4                                                 0.000036
# 81) G2                                                 0.000031
# 82) OTHER                                              0.000008

# %%
global_importances = pd.Series(rf_mod.feature_importances_, index=X_train.columns)
global_importances.sort_values(ascending=True, inplace=True)
global_importances.plot.barh(color='grey')
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Feature Importance")
# Out:
# Text(0.5, 1.0, 'Feature Importance')
