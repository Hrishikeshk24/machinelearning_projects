# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# Cython              codeop              modulefinder        soupsieve
# IPython             collections         more_itertools      sphinx
# OpenSSL             colorama            mpmath              sphinxcontrib
# PIL                 colorsys            msgpack             sphinxify
# PyQt5               commctrl            msilib              sphinxthread
# TBB                 compileall          msvcrt              spyder
# __future__          comtypes            multipledispatch    spyder_kernels
# _abc                concurrent          multiprocessing     sqlalchemy
# _aix_support        conda               munkres             sqlite3
# _ast                conda_build         mypy_extensions     sre_compile
# _asyncio            conda_content_trust nacl                sre_constants
# _bisect             conda_env           navigator_updater   sre_parse
# ...

# %%
import math

# %%
print("Pi: ", math.pi)
# Out:
# Pi:  3.141592653589793

# %%
print("e: ", math.e)
# Out:
# e:  2.718281828459045

# %%
math.ceil(8.1)
# Out:
# 9

# %%
math.floor(8.1)
# Out:
# 8

# %%
math.pow(2, 4)
# Out:
# 16.0

# %%
math.sqrt(24)
# Out:
# 4.898979485566356

# %%
math.factorial(6)
# Out:
# 720

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hrishikesh.harishkum'

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\hrishikesh.harishkum\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'USC-W-CCG1QG3',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONDA_DEFAULT_ENV': 'base',
#         'CONDA_EXE': 'C:\\Users\\hrishikesh.harishkum\\Anaconda3\\Scripts\\conda.exe',
#         'CONDA_PROMPT_MODIFIER': '(base) ',
#         'CONDA_PYTHON_EXE': 'C:\\Users\\hrishikesh.harishkum\\Anaconda3\\python.exe',
#         'CONDA_SHLVL': '1',
#         'CV_INSTANCE001': 'C:\\Program Files\\Commvault\\ContentStore\\Base',
#         'DEFLOGDIR': 'C:\\ProgramData\\McAfee\\Endpoint Security\\Logs',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
# ...

# %%
user = os.environ["USERNAME"] 

print("User: ", user)
# Out:
# User:  hrishikesh.harishkum

# %%
path = os.environ["PATH"] 

print("Path: ", path)
# Out:
# Path:  C:\Users\hrishikesh.harishkum\Anaconda3\Lib\site-packages\daal4py\oneapi;C:\Users\hrishikesh.harishkum\Anaconda3\lib\site-packages\daal4py\oneapi;C:\Users\hrishikesh.harishkum\Anaconda3\Lib\site-packages\daal4py\oneapi;C:\Users\hrishikesh.harishkum\Anaconda3\lib\site-packages\daal4py\oneapi;C:\Users\hrishikesh.harishkum\Anaconda3\Lib\site-packages\daal4py\oneapi;C:\Users\hrishikesh.harishkum\Anaconda3\lib\site-packages\daal4py\oneapi;C:\Users\hrishikesh.harishkum\Anaconda3;C:\Users\hrishikesh.harishkum\Anaconda3\Library\mingw-w64\bin;C:\Users\hrishikesh.harishkum\Anaconda3\Library\usr\bin;C:\Users\hrishikesh.harishkum\Anaconda3\Library\bin;C:\Users\hrishikesh.harishkum\Anaconda3\Scripts;C:\Users\hrishikesh.harishkum\Anaconda3\bin;C:\Users\hrishikesh.harishkum\Anaconda3\condabin;C:\Users\hrishikesh.harishkum\Anaconda3;C:\Users\hrishikesh.harishkum\Anaconda3\Library\mingw-w64\bin;C:\Users\hrishikesh.harishkum\Anaconda3\Library\usr\bin;C:\Users\hrishikesh.harishkum\Anaconda3\Libr
# ...

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.astropy',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.spyder-py3',
#  '01-ClassesAndInstances.ipynb',
#  '3D Objects',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'brand_new_workbook.xlsx',
#  'company_revenue.xlsx',
#  'ConditionalFormatting.ipynb',
#  'Contacts',
#  'Cookies',
#  'Coursera - Python for Data Science, AI & Development.ipynb',
#  'Coursera - Statistics.ipynb',
#  'Data Cleaning using Python with Pandas Library.ipynb',
#  'Desktop',
#  'dimensions.xlsx',
#  'Documents',
#  'Downloads',
#  'EDX - Computing in Python I - Fundamentals and Procedural Programming.ipynb',
#  'excel_resizing.xlsx',
#  'Exploratory Data Analysis.ipynb',
#  'Favorites',
#  'FiltersAndSorts.ipynb',
#  'First.ipynb',
#  'google-python-exercises',
#  'hello.py',
#  'hrishikesh.harishkum_NTUSER.DAT',
#  'IntelGraphicsProfiles',
#  'it_pycipydj_02_assets',
#  'Jedi',
#  'Links',
# ...

# %%
os.mkdir("./my_temp_dir1")

# %%
os.listdir(".")
# Out:
# ['.anaconda',
#  '.astropy',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.spyder-py3',
#  '01-ClassesAndInstances.ipynb',
#  '3D Objects',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'brand_new_workbook.xlsx',
#  'company_revenue.xlsx',
#  'ConditionalFormatting.ipynb',
#  'Contacts',
#  'Cookies',
#  'Coursera - Python for Data Science, AI & Development.ipynb',
#  'Coursera - Statistics.ipynb',
#  'Data Cleaning using Python with Pandas Library.ipynb',
#  'Desktop',
#  'dimensions.xlsx',
#  'Documents',
#  'Downloads',
#  'EDX - Computing in Python I - Fundamentals and Procedural Programming.ipynb',
#  'excel_resizing.xlsx',
#  'Exploratory Data Analysis.ipynb',
#  'Favorites',
#  'FiltersAndSorts.ipynb',
#  'First.ipynb',
#  'google-python-exercises',
#  'hello.py',
#  'hrishikesh.harishkum_NTUSER.DAT',
#  'IntelGraphicsProfiles',
#  'it_pycipydj_02_assets',
#  'Jedi',
#  'Links',
# ...

# %%
os.rename("my_temp_dir1", "my_new_dir")

# %%
os.listdir(".")
# Out:
# ['.anaconda',
#  '.astropy',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.spyder-py3',
#  '01-ClassesAndInstances.ipynb',
#  '3D Objects',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'brand_new_workbook.xlsx',
#  'company_revenue.xlsx',
#  'ConditionalFormatting.ipynb',
#  'Contacts',
#  'Cookies',
#  'Coursera - Python for Data Science, AI & Development.ipynb',
#  'Coursera - Statistics.ipynb',
#  'Data Cleaning using Python with Pandas Library.ipynb',
#  'Desktop',
#  'dimensions.xlsx',
#  'Documents',
#  'Downloads',
#  'EDX - Computing in Python I - Fundamentals and Procedural Programming.ipynb',
#  'excel_resizing.xlsx',
#  'Exploratory Data Analysis.ipynb',
#  'Favorites',
#  'FiltersAndSorts.ipynb',
#  'First.ipynb',
#  'google-python-exercises',
#  'hello.py',
#  'hrishikesh.harishkum_NTUSER.DAT',
#  'IntelGraphicsProfiles',
#  'it_pycipydj_02_assets',
#  'Jedi',
#  'Links',
# ...

# %%
os.rmdir("my_new_dir")

# %%
os.listdir(".")
# Out:
# ['.anaconda',
#  '.astropy',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.spyder-py3',
#  '01-ClassesAndInstances.ipynb',
#  '3D Objects',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'brand_new_workbook.xlsx',
#  'company_revenue.xlsx',
#  'ConditionalFormatting.ipynb',
#  'Contacts',
#  'Cookies',
#  'Coursera - Python for Data Science, AI & Development.ipynb',
#  'Coursera - Statistics.ipynb',
#  'Data Cleaning using Python with Pandas Library.ipynb',
#  'Desktop',
#  'dimensions.xlsx',
#  'Documents',
#  'Downloads',
#  'EDX - Computing in Python I - Fundamentals and Procedural Programming.ipynb',
#  'excel_resizing.xlsx',
#  'Exploratory Data Analysis.ipynb',
#  'Favorites',
#  'FiltersAndSorts.ipynb',
#  'First.ipynb',
#  'google-python-exercises',
#  'hello.py',
#  'hrishikesh.harishkum_NTUSER.DAT',
#  'IntelGraphicsProfiles',
#  'it_pycipydj_02_assets',
#  'Jedi',
#  'Links',
# ...

# %%
os.mkdir("./my_temp_dir")

# %%
cwd = os.getcwd()

cwd
# Out:
# 'C:\\Users\\hrishikesh.harishkum'

# %%
os.path.isdir(cwd)
# Out:
# True

# %%
os.path.isfile(cwd)
# Out:
# False

# %%
from os import path

# %%
path.isdir(cwd)
# Out:
# True

# %%
path.isfile(cwd)
# Out:
# False

# %%
path.exists("my_temp_dir")
# Out:
# True

# %%
path.exists("random_dir")
# Out:
# False

# %%
import random

# %%
random.random()
# Out:
# 0.11293089025651448

# %%
random.random()
# Out:
# 0.5163863728012367

# %%
random.randint(0, 10)
# Out:
# 3

# %%
random.randint(0, 10)
# Out:
# 0

# %%
random.randint(0, 10)
# Out:
# 3

# %%
my_list = ["John", "Roy", True, 34, "Rose", 12.9]

# %%
random.choice(my_list)
# Out:
# 'Rose'

# %%
random.choice(my_list)
# Out:
# 12.9

# %%
random.choice(my_list)
# Out:
# 12.9

# %%
import datetime

# %%
datetime.date.today()
# Out:
# datetime.date(2022, 1, 22)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 1, 22, 12, 37, 19, 373193)
