# %%
# !python --version
# Out:
# Python 3.9.7

# %%
import openpyxl

# %%
work_book=openpyxl.load_workbook("testexcel.xlsx")

# %%
work_book.sheetnames
# Out:
# ['Sheet1', 'Sports Day', 'Camping 2022', 'Sheet2']

# %%
work_book["Sheet1"]
# Out:
# <Worksheet "Sheet1">

# %%
sheet_obj = work_book["Sheet1"]
sheet_obj
# Out:
# <Worksheet "Sheet1">

# %%
sheet_obj.title
# Out:
# 'Sheet1'

# %%
sheet_obj['A1']
# Out:
# <Cell 'Sheet1'.A1>

# %%
sheet_obj['A1'].value
# Out:
# ' Full Name'

# %%
cell=sheet_obj['A1']

# %%
type(cell)
# Out:
# openpyxl.cell.cell.Cell

# %%
dir(cell)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_bind_value',
#  '_comment',
#  '_hyperlink',
#  '_style',
#  '_value',
#  'alignment',
#  'base_date',
#  'border',
#  'check_error',
#  'check_string',
#  'col_idx',
#  'column',
#  'column_letter',
#  'comment',
#  'coordinate',
#  'data_type',
#  'encoding',
#  'fill',
#  'font',
#  'has_style',
#  'hyperlink',
#  'internal_value',
#  'is_date',
#  'number_format',
#  'offset',
#  'parent',
#  'pivotButton',
#  'protection',
#  'quotePrefix',
#  'row',
#  'style',
#  'style_id',
#  'value']

# %%
cell.row
# Out:
# 1

# %%
cell.column
# Out:
# 1

# %%
cell.value
# Out:
# ' Full Name'

# %%
cell.number_format
# Out:
# 'General'

# %%
cell.coordinate
# Out:
# 'A1'

# %%
cell.data_type
# Out:
# 's'

# %%
sheet_obj.cell(row=1, column=1)
# Out:
# <Cell 'Sheet1'.A1>

# %%
sheet_obj['A1':'D2']
# Out:
# ((<Cell 'Sheet1'.A1>,
#   <Cell 'Sheet1'.B1>,
#   <Cell 'Sheet1'.C1>,
#   <Cell 'Sheet1'.D1>),
#  (<Cell 'Sheet1'.A2>,
#   <Cell 'Sheet1'.B2>,
#   <Cell 'Sheet1'.C2>,
#   <Cell 'Sheet1'.D2>))

# %%
sheet_obj['A1':'D2'].value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_16072/3436137980.py in <module>
# ----> 1 sheet_obj['A1':'D2'].value
#
# AttributeError: 'tuple' object has no attribute 'value'

# %%
for rows in sheet_obj['A1':'G1']:
    
    for cell in rows:
        
        print(cell.coordinate, cell.value)
        ##print(cell.value)
# Out:
# A1  Full Name
# B1 Spouse's Name
# C1 Sponsor 2020
# D1 Member 2020
# E1 Member Category
# F1 Amount
# G1 PAYMENT METHOD

# %%
max_col=sheet_obj.max_column
max_row=sheet_obj.max_row

max_row
# Out:
# 212

# %%
max_col
# Out:
# 32

# %%
sheet_obj.cell(row=1, column=2)
# Out:
# <Cell 'Sheet1'.B1>

# %%
for i in range(1, max_col+1):
    cell_obj = sheet_obj.cell(row=2,column=i)
    print(cell_obj.coordinate, cell_obj.value)
# Out:
# A2 Vithal Kulkarni
# B2 None
# C2 =IF(OR(K2<>0,L2<>0,M2<>0),"Y"," ")
# D2 =IF(OR(C2="Y",J2<>0, Q2<>0),"Y"," ")
# E2 =IF(D2="Y", IF(K2<>0,"GOLD", IF(L2<>0,"SILVER",IF(M2<>0,"BRONZE", IF(Q2<>0,"STUDENT","MEMBER"))))," ")
# F2 =R2
# G2 None
# H2 None
# I2 N
# J2 0
# K2 0
# L2 1
# M2 0
# N2 0
# O2 0
# P2 0
# Q2 0
# R2 =(J2*40)+(K2*200)+(L2*150)+(M2*100)+(N2*15)+(O2*20)+(Q2*20)+(P2*5)
# S2 None
# T2 None
# U2 2818275307
# V2 ajaypandith@yahoo.com
# W2 None
# X2 None
# Y2 None
# Z2 None
# AA2 None
# AB2 None
# AC2 None
# AD2 None
# AE2 None
# AF2 CASH

# %%
cell_ob=sheet_obj.cell(row=1,column=2)

cell_ob
# Out:
# <Cell 'Sheet1'.B1>

# %%
cell_ob.value
# Out:
# "Spouse's Name"

# %%
c_ob = sheet_obj['b1']

c_ob
# Out:
# <Cell 'Sheet1'.B1>

# %%
c_ob.value
# Out:
# "Spouse's Name"

# %%
c_ob1 = sheet_obj['a1':'c1']

c_ob1
# Out:
# ((<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>, <Cell 'Sheet1'.C1>),)

# %%
c_ob1.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_16072/2109163691.py in <module>
# ----> 1 c_ob1.value
#
# AttributeError: 'tuple' object has no attribute 'value'

# %%
max_col
# Out:
# 32

# %%
max_row
# Out:
# 212

# %%
for i in range(1, max_col+1):  
    
    cell_obj = sheet_obj.cell(row=1,column=i)
    print(cell_obj.value)
# Out:
#  Full Name
# Spouse's Name
# Sponsor 2020
# Member 2020
# Member Category
# Amount
# PAYMENT METHOD
# 2019 -Spon
# 2019 Mem
# Membership Ticket - 40$
# Gold - 200$
# Silver - 150$
# Bronze - 100$
# Event Ticket - Member - 15$
# Event Ticket - Non-Member - 20$
# Event Ticket - Kids above 12 years of age - 5$
# Student Membership - 20$
# Total Price
# Comments
# None
# Primary Contact #
# Primary Email ID
# Secondary Contact #
# Secondary Email ID
# None
# None
# None
# None
# None
# None
# None
# None

# %%
for i in range(1, max_row+1):
    
    cell_obj = sheet_obj.cell(row=i,column=1)
    print(cell_obj.value)
# Out:
#  Full Name
# Vithal Kulkarni
# Malini Mulbagal
# Tanuja Basavaraj
# Dhanraj Balakrishna
# Grama Bhashyam
# Hrishikesh Mysore Harishkumar
# Vadiraj Purohit
# Ramdas Mayya
# Kiran Alemada
# Dayananda  Rangegowda
# Chethan Puttarajappa
# Ramaprasad Lakshminarayana
# Amar Kamath Kasargod
# None
# None
# Vinay Gowda
# Vijay Chegareddy
# Aswath Shetty
# Harsha Anish
# Ranganath Dasappa
# Vithal Kulkarni
# Janaki Vallabha
# Ganga
# Hrishikesh Mysore Harishkumar
# Sudharshan Chadaga
# Naveen Hanuman
# Edwin
# None
# None
# Geetha Byregowda
# Vithal Kulkarni
# Dayanand Rangegowda
# Pavan Dhananjay
# Raghu
# Ganga Kalangi
# Amar Kamath
# Renukesh
# Hrishikesh
# Kartheek
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
sheet_obj['a1':'c1']
# Out:
# ((<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>, <Cell 'Sheet1'.C1>),)

# %%
sheet_obj['a1':'c3']
# Out:
# ((<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>, <Cell 'Sheet1'.C1>),
#  (<Cell 'Sheet1'.A2>, <Cell 'Sheet1'.B2>, <Cell 'Sheet1'.C2>),
#  (<Cell 'Sheet1'.A3>, <Cell 'Sheet1'.B3>, <Cell 'Sheet1'.C3>))

# %%
for rows in sheet_obj['A1':'C3']:
    ## as this is a rectangular region, we need a nested FOR loop. Outer loop is a row and inner loop corresponds to the 
    for cell in rows:                     ## individual cell.For ranges, we always need nested for loops to iterate.
        
        print(cell.coordinate, cell.value, cell.data_type)
        
    print('-----------------------')
# Out:
# A1  Full Name s
# B1 Spouse's Name s
# C1 Sponsor 2020 s
# -----------------------
# A2 Vithal Kulkarni s
# B2 None n
# C2 =IF(OR(K2<>0,L2<>0,M2<>0),"Y"," ") f
# -----------------------
# A3 Malini Mulbagal s
# B3 None n
# C3 =IF(OR(K3<>0,L3<>0,M3<>0),"Y"," ") f
# -----------------------

# %%
for row in sheet_obj.iter_rows(min_row=1,
                              max_row=2,
                              min_col=1,
                              max_col=3):
    print(row)
# Out:
# (<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>, <Cell 'Sheet1'.C1>)
# (<Cell 'Sheet1'.A2>, <Cell 'Sheet1'.B2>, <Cell 'Sheet1'.C2>)

# %%
sheet_obj['a1':'c2']
# Out:
# ((<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>, <Cell 'Sheet1'.C1>),
#  (<Cell 'Sheet1'.A2>, <Cell 'Sheet1'.B2>, <Cell 'Sheet1'.C2>))

# %%
sheet_obj['a1':'c2'].value  ##will not work
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_16072/1663561824.py in <module>
# ----> 1 sheet_obj['a1':'c2'].value
#
# AttributeError: 'tuple' object has no attribute 'value'

# %%
for row in sheet_obj.iter_rows(min_row=1,        ## But this will work
                              max_row=2,
                              min_col=1,
                              max_col=3,
                              values_only=True):
    print(row)
# Out:
# (' Full Name', "Spouse's Name", 'Sponsor 2020')
# ('Vithal Kulkarni', None, '=IF(OR(K2<>0,L2<>0,M2<>0),"Y"," ")')

# %%
for row in sheet_obj.iter_rows(min_row=1,        ## But this will work
                              max_row=2,
                              min_col=1,
                              max_col=3,
                              values_only=False):
    print(row)
# Out:
# (<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>, <Cell 'Sheet1'.C1>)
# (<Cell 'Sheet1'.A2>, <Cell 'Sheet1'.B2>, <Cell 'Sheet1'.C2>)

# %%
for col in sheet_obj.iter_cols(min_row=1,       
                              max_row=2,
                              min_col=1,
                              max_col=3
                              ):
    print(col)
# Out:
# (<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.A2>)
# (<Cell 'Sheet1'.B1>, <Cell 'Sheet1'.B2>)
# (<Cell 'Sheet1'.C1>, <Cell 'Sheet1'.C2>)

# %%
for col in sheet_obj.iter_cols(min_row=1,       
                              max_row=2,
                              min_col=1,
                              max_col=2,
                              values_only=True):
    print(col)
# Out:
# (' Full Name', 'Vithal Kulkarni')
# ("Spouse's Name", None)

# %%
for col in sheet_obj.iter_cols(min_row=1,       
                              max_row=3,
                              min_col=1,
                              max_col=2,
                              values_only=False):
    print(col)
# Out:
# (<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.A2>, <Cell 'Sheet1'.A3>)
# (<Cell 'Sheet1'.B1>, <Cell 'Sheet1'.B2>, <Cell 'Sheet1'.B3>)

# %%
for col in sheet_obj.iter_cols(min_row=1,       
                              max_row=3,
                              min_col=1,
                              max_col=2,
                              values_only=False):
    print(col[0])
# Out:
# <Cell 'Sheet1'.A1>
# <Cell 'Sheet1'.B1>

# %%
for row in sheet_obj.iter_rows(min_row=1,       
                              max_row=3,
                              min_col=1,
                              max_col=2,
                              values_only=False):
    print(row)
# Out:
# (<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>)
# (<Cell 'Sheet1'.A2>, <Cell 'Sheet1'.B2>)
# (<Cell 'Sheet1'.A3>, <Cell 'Sheet1'.B3>)

# %%
for row in sheet_obj.iter_rows(min_row=2,       
                              max_row=7,
                              min_col=1,
                              max_col=5,
                              values_only=True):
    print(row)
# Out:
# ('Vithal Kulkarni', None, '=IF(OR(K2<>0,L2<>0,M2<>0),"Y"," ")', '=IF(OR(C2="Y",J2<>0, Q2<>0),"Y"," ")', '=IF(D2="Y", IF(K2<>0,"GOLD", IF(L2<>0,"SILVER",IF(M2<>0,"BRONZE", IF(Q2<>0,"STUDENT","MEMBER"))))," ")')
# ('Malini Mulbagal', None, '=IF(OR(K3<>0,L3<>0,M3<>0),"Y"," ")', '=IF(OR(C3="Y",J3<>0, Q3<>0),"Y"," ")', '=IF(D3="Y", IF(K3<>0,"GOLD", IF(L3<>0,"SILVER",IF(M3<>0,"BRONZE", IF(Q3<>0,"STUDENT","MEMBER"))))," ")')
# ('Tanuja Basavaraj', None, '=IF(OR(K4<>0,L4<>0,M4<>0),"Y"," ")', '=IF(OR(C4="Y",J4<>0, Q4<>0),"Y"," ")', '=IF(D4="Y", IF(K4<>0,"GOLD", IF(L4<>0,"SILVER",IF(M4<>0,"BRONZE", IF(Q4<>0,"STUDENT","MEMBER"))))," ")')
# ('Dhanraj Balakrishna', None, '=IF(OR(K5<>0,L5<>0,M5<>0),"Y"," ")', '=IF(OR(C5="Y",J5<>0, Q5<>0),"Y"," ")', '=IF(D5="Y", IF(K5<>0,"GOLD", IF(L5<>0,"SILVER",IF(M5<>0,"BRONZE", IF(Q5<>0,"STUDENT","MEMBER"))))," ")')
# ('Grama Bhashyam', None, '=IF(OR(K6<>0,L6<>0,M6<>0),"Y"," ")', '=IF(OR(C6="Y",J6<>0, Q6<>0),"Y"," ")', '=IF(D6="Y", IF(K6<>0,"GOLD", IF(L6<>0,"SILVER",IF(M6<>0,"BRONZE", IF(Q6<>0,"STUDENT","MEMBER"))))," ")')
# ('Hrishikesh Mysore Harishkumar', None, '=IF(OR(K7<>0,L7<>0,M7<>0),"Y"," ")', '=IF(OR(C7="Y",J7<>0, Q7<>0),"Y"," ")', '=IF(D7="Y", IF(K7<>0,"GOLD", IF(L7<>0,"SILVER",IF(M7<>0,"BRONZE", IF(Q7<>0,"STUDENT","MEMBER"))))," ")')

# %%
import json

# %%
revenues={}

# %%
work_book=openpyxl.load_workbook("testexcel.xlsx")

# %%
work_book.sheetnames
# Out:
# ['Sheet1', 'Sports Day', 'Camping 2022', 'Sheet2']

# %%
sheet_obj=work_book["Sheet1"]

# %%
sheet_obj
# Out:
# <Worksheet "Sheet1">

# %%
sheet_obj['a1'].value
# Out:
# ' Full Name'

# %%
for row in sheet_obj.iter_rows(min_row=2,       
                              max_row=7,
                              min_col=1,
                              max_col=5,
                              values_only=True):
    print(row[0], row[1], row[2],row[3],row[4])
# Out:
# Vithal Kulkarni Y Y SILVER 150
# Malini Mulbagal Y Y SILVER 150
# Tanuja Basavaraj Y Y SILVER 150
# Dhanraj Balakrishna Y Y BRONZE 100
# Grama Bhashyam None Y MEMBER 40
# Hrishikesh Mysore Harishkumar Y Y SILVER 150

# %%
for row in sheet_obj.iter_rows(min_row=2,       
                              max_row=7,
                              min_col=1,
                              max_col=5,
                              values_only=True):
    
    rep=row[0]
    rev_details = {
        "Sponsor" : row[1],    
        "Member"  : row[2],    
        "Category": row[3],
        "Amount"  : row[4] 
    }
    
    revenues[rep] = rev_details

# %%
print(json.dumps(revenues, indent=4, sort_keys=False))
# Out:
# {
#     "Vithal Kulkarni": {
#         "Sponsor": "Y",
#         "Member": "Y",
#         "Category": "SILVER",
#         "Amount": 150
#     },
#     "Malini Mulbagal": {
#         "Sponsor": "Y",
#         "Member": "Y",
#         "Category": "SILVER",
#         "Amount": 150
#     },
#     "Tanuja Basavaraj": {
#         "Sponsor": "Y",
#         "Member": "Y",
#         "Category": "SILVER",
#         "Amount": 150
#     },
#     "Dhanraj Balakrishna": {
#         "Sponsor": "Y",
#         "Member": "Y",
#         "Category": "BRONZE",
#         "Amount": 100
#     },
#     "Grama Bhashyam": {
#         "Sponsor": null,
#         "Member": "Y",
#         "Category": "MEMBER",
#         "Amount": 40
#     },
#     "Hrishikesh Mysore Harishkumar": {
#         "Sponsor": "Y",
#         "Member": "Y",
#         "Category": "SILVER",
#         "Amount": 150
#     }
# }

# %%
import openpyxl

# %%
work_book=openpyxl.Workbook()

# %%
work_book.sheetnames
# Out:
# ['Sheet']

# %%
sheet=work_book["Sheet"]

# %%
sheet
# Out:
# <Worksheet "Sheet">

# %%
sheet['A1']= "hi"
sheet['B1']= "My name is "
sheet['C1']= "hrishi"

# %%
work_book["Sheet"]["c1"].value
# Out:
# 'hrishi'

# %%
work_book.save("practiceexcel.xlsx")

# %%
sheet.calculate_dimension()
# Out:
# 'A1:C1'

# %%
sheet.append(['my','kids are', 'raam and dia'])

# %%
work_book.save("practiceexcel.xlsx")

# %%
sheet.append(['my','wife is', 'shru'])

# %%
sheet.calculate_dimension()
# Out:
# 'A1:C3'

# %%
sheet.insert_rows(idx=2,amount=4)

# %%
sheet.calculate_dimension()
# Out:
# 'A1:C7'

# %%
sheet.insert_cols(idx=2,amount=4)

# %%
sheet.calculate_dimension()
# Out:
# 'A1:G7'

# %%
work_book.save("practiceexcel.xlsx")

# %%
sheet.delete_rows(idx=2,amount=4)

# %%
sheet.calculate_dimension()
# Out:
# 'A1:G3'

# %%
sheet.delete_cols(idx=2,amount=4)

# %%
sheet.calculate_dimension()
# Out:
# 'A1:C3'

# %%
work_book.save("practiceexcel.xlsx")

# %%
sheet.title
# Out:
# 'Sheet'

# %%
sheet.title='Firstsheet'

# %%
work_book.save("practiceexcel.xlsx")

# %%
## Its also possible to write data into sheets using a list of lists.Here is a list of list

data =[['Planet', 'Radius (km)', 'Distance from Sun (M Km)'],
      ['Earth', 6371, 150], ['Mars', 3389, 228], ['Mercury', 2440, 58]]

# %%
planet_wb=openpyxl.Workbook()

# %%
planet_wb.active
# Out:
# <Worksheet "Planets">

# %%
planet_wb.sheetnames
# Out:
# ['Planets']

# %%
planet=planet_wb['Planets']

# %%
planet.title='Planets'

# %%
planet.title
# Out:
# 'Planets'

# %%
for row in data:
    planet.append(row)

# %%
planet
# Out:
# <Worksheet "Planets">

# %%
planet_wb.save("Planets.xlsx")

# %%
planet.delete_rows(idx=5,amount=4)

# %%
planet_wb.save("Planets.xlsx")

# %% [markdown]
# ## Freezing panes

# %%
work_book=openpyxl.load_workbook("Planets.xlsx")

# %%
work_book.active
# Out:
# <Worksheet "Planets">

# %%
work_book.sheetnames
# Out:
# ['Planets']

# %%
sheet=work_book["Planets"]

# %%
sheet
# Out:
# <Worksheet "Planets">

# %%
sheet['A1']
# Out:
# <Cell 'Planets'.A1>

# %%
sheet['a1':'c4']
# Out:
# ((<Cell 'Planets'.A1>, <Cell 'Planets'.B1>, <Cell 'Planets'.C1>),
#  (<Cell 'Planets'.A2>, <Cell 'Planets'.B2>, <Cell 'Planets'.C2>),
#  (<Cell 'Planets'.A3>, <Cell 'Planets'.B3>, <Cell 'Planets'.C3>),
#  (<Cell 'Planets'.A4>, <Cell 'Planets'.B4>, <Cell 'Planets'.C4>))

# %%
sheet.unfreeze_panes='b1'

# %%
work_book.save("Planets.xlsx")

# %%
for row in data:
    sheet.append(row)

# %%
data = [["Champion", "Year"],
        ["France", 2018],
        ["Spain", 2010],
        ["Italy", 2006],
        ["France", 1998],
        ["Brazil", 1994],
        ["Argentina", 1986],
        ["Italy", 1982],
        ["Argentina", 1978],
        ["Germany", 1974],
        ["Brazil", 1970],
        ["England", 1966],
        ["Brazil", 1962],
        ["Brazil", 1958],
        ["Germany", 2014],
        ["Germany", 1954],
        ["Uruguay", 1950],
        ["Italy", 1938],
        ["Italy", 1934],
        ["Uruguay", 1930],
        ["Germany", 1990],
        ["Brazil", 2002]]

# %%
import openpyxl

# %%
work_book=openpyxl.Workbook()

# %%
work_book.active
# Out:
# <Worksheet "Sheet">

# %%
work_book.sheetnames
# Out:
# ['Sheet']

# %%
sheet=work_book['Sheet']

# %%
sheet['a1']
# Out:
# <Cell 'Sheet'.A1>

# %%
sheet['a1'].value

# %%
for row in data:
    sheet.append(row)

# %%
work_book.save('WCwinners.xlsx')

# %%
sheet['b3'].value
# Out:
# 2018

# %%
sheet.calculate_dimension()
# Out:
# 'A1:B23'

# %%
sheet.auto_filter.ref = sheet.calculate_dimension()  ## important

# %%
work_book.save('WCwinners.xlsx')

# %%
sheet.auto_filter.add_filter_column(0,['Brazil', 'Italy', 'Argentina'])

## The first input arg is the column numbver which is 0 (COl A) and the sec input arg is the list of values.

# %%
work_book.save('WCwinners.xlsx')

# %%
## As you see above, it is not filtered as we expected. We needed only italy, Brazil and Argentina.
## There is a little bug in the openpyxl filtering API.
## We need to reapply the filter manually opening the workbook.
## its definitely a glitch in the way in whihc the filter API in openpyxl works. 
## Lets do additional ops.

# %%
## Lets get the full extent of the data by using the negative indexing operator.
sheet['B'][1], sheet['B'][-1]
# Out:
# (<Cell 'Sheet'.B2>, <Cell 'Sheet'.B23>)

# %%
range_str = sheet['B'][1].coordinate + ':' + sheet['B'][-1].coordinate

range_str ## This gives us a nice range string representing all of the data present in column B.
# Out:
# 'B2:B23'

# %%
sheet.auto_filter.add_sort_condition(range_str, descending = True)

# %%
work_book.save('WCwinners.xlsx')

# %%
## Again we see that the data is not exactly the way we would need. We can manually remediate this by clicking on the data 
## tab in excel and click reapply.After reapplying :

# %%
## Thus we saw that even though there is a little bit of a glitch on the API's in openpyxl for filtering and sorting,
## they still allow us to accomplish some pretty cool stuff.

# %%
import openpyxl

# %%
work_book=openpyxl.Workbook()

# %%
work_book.active
# Out:
# <Worksheet "Sheet">

# %%
work_book.sheetnames
# Out:
# ['Sheet']

# %%
sheet_obj=work_book['Sheet']

# %%
sheet_obj['c1']='A high row'
sheet_obj['d4']='A wide col'

# %%
sheet_obj.row_dimensions[1].height =70
sheet_obj.column_dimensions['D'].width =60

# %%
work_book.save('resizing.xlsx')

# %%
work_book.create_sheet(title ='Brandnewsheet',index = 0)
# Out:
# <Worksheet "Brandnewsheet">

# %%
work_book.sheetnames
# Out:
# ['Brandnewsheet', 'Sheet']

# %%
new_sheet=work_book.active

# %%
new_sheet
# Out:
# <Worksheet "Brandnewsheet">

# %%
work_book.save('dimensions.xlsx')

# %%
new_sheet
# Out:
# <Worksheet "Brandnewsheet">

# %%
new_sheet.merge_cells('A1:D3')

# %%
work_book.save('dimensions.xlsx')

# %%
new_sheet['d4']='hi'

# %%
work_book.save('dimensions.xlsx')

# %%
new_sheet['c3']='data in merged cell'

## C2 is in the middle of the cells A1:D3 that were merged. ## This results in an error.
    ## Error means that we cannot change the values of an individual cell within a merged cell unless we use the cell address 
    ## of the top left corner in this case A1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_19956/3204385686.py in <module>
# ----> 1 new_sheet['c3']='data in merged cell'
#
# ~\Anaconda3\lib\site-packages\openpyxl\worksheet\worksheet.py in __setitem__(self, key, value)
#     311
#     312     def __setitem__(self, key, value):
# --> 313         self[key].value = value
#     314
#     315
#
# AttributeError: 'MergedCell' object attribute 'value' is read-only

# %%
new_sheet['a1']='data in merged cell'

# %%
work_book.save('dimensions.xlsx')

# %%
from openpyxl.styles import Alignment

# %%
 new_sheet['A1'].alignment = Alignment(horizontal='center')

# %%
work_book.save('dimensions.xlsx')

# %%
 new_sheet['A1'].alignment = Alignment(vertical='center') ## When we do this, the horizontal alignment we did before will
    ## NOT LAST.

# %%
work_book.save('dimensions.xlsx')

# %%
 new_sheet['A1'].alignment = Alignment(horizontal = 'right',vertical='top')

# %%
work_book.save('dimensions.xlsx')

# %%
new_sheet.merge_cells('B5:G5') ## equivalent of merge across operation

# %%
new_sheet['B5'] ='We just merged the cells in the same row'

# %%
new_sheet['B5'].alignment = Alignment(horizontal='center')

# %%
work_book.save('dimensions.xlsx')
