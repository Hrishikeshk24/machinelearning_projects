# %%
fruits_list = ["Apple", "Grapes", "Mango", "Bananas"]

# %%
def change_list(fruits_list):
    
    fruits_list[0] = "Kiwi"
    
    print("Inside the function: ", fruits_list)

change_list(fruits_list)
print()
print("Outside the function: ", fruits_list)
# Out:
# Inside the function:  ['Kiwi', 'Grapes', 'Mango', 'Bananas']
#
# Outside the function:  ['Kiwi', 'Grapes', 'Mango', 'Bananas']

# %%
fruits_list = ["Apple", "Grapes"]

# %%
change_list(fruits_list)
# Out:
# Inside the function:  ['Kiwi', 'Grapes']

# %%
fruits_list
# Out:
# ['Kiwi', 'Grapes']

# %%
fruits_list = ["Apple", "Grapes", "Mango", "Bananas"]

def change_list(fruits_list):
    
    fruits_list.append("Kiwi")
    
    print("Inside the function: ", fruits_list)

change_list(fruits_list)
print()
print("Outside the function: ", fruits_list)
# Out:
# Inside the function:  ['Apple', 'Grapes', 'Mango', 'Bananas', 'Kiwi']
#
# Outside the function:  ['Apple', 'Grapes', 'Mango', 'Bananas', 'Kiwi']

# %%
fruits_list = ["Apple", "Grapes", "Mango", "Bananas"]

def change_list(fruits_list):
    
    fruits_list.remove("Apple")
    
    print("Inside the function: ", fruits_list)

change_list(fruits_list)
print()
print("Outside the function: ", fruits_list)
# Out:
# Inside the function:  ['Grapes', 'Mango', 'Bananas']
#
# Outside the function:  ['Grapes', 'Mango', 'Bananas']

# %%
fruits_list = ["Apple", "Grapes", "Mango", "Bananas"]

def sort_items_and_remove_last(my_list):
    my_list.sort()
    my_list.pop()
    
    print("Inside the function", my_list)

# %%
sort_items_and_remove_last(fruits_list)
# Out:
# Inside the function ['Apple', 'Bananas', 'Grapes']

# %%
fruits_list
# Out:
# ['Apple', 'Bananas', 'Grapes']

# %%
car_speeds_dictionary = {
    "Camry": 120,
    "Accord": 130,
    "Cayenne": 250,
    "Mini Cooper": 100
}

# %%
def change_dictionary(dictionary):
    
    dictionary["Mustang"] = 429
    
    print("Inside the function: ", dictionary)

# %%
change_dictionary(car_speeds_dictionary)
# Out:
# Inside the function:  {'Camry': 120, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100, 'Mustang': 429}

# %%
car_speeds_dictionary
# Out:
# {'Camry': 120,
#  'Accord': 130,
#  'Cayenne': 250,
#  'Mini Cooper': 100,
#  'Mustang': 429}

# %%
car_speeds_dictionary = {
    "Camry": 120,
    "Accord": 130,
    "Cayenne": 250,
    "Mini Cooper": 100
}

# %%
def change_dictionary(car_speeds_dictionary):
    
    car_speeds_dictionary ={"BMW": 200}
    
    print("Inside the function: ", car_speeds_dictionary)
change_dictionary(car_speeds_dictionary)
print()
print("Outside the function: ", car_speeds_dictionary)
# Out:
# Inside the function:  {'BMW': 200}
#
# Outside the function:  {'Camry': 120, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}

# %%
car_speeds_dictionary
# Out:
# {'Camry': 120, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}

# %%
car_speeds_dictionary = {
    "Camry": 120,
    "Accord": 130,
    "Cayenne": 250,
    "Mini Cooper": 100
}

def change_dictionary(car_speeds_dictionary):
    
    car_speeds_dictionary["Camry"] = 200
    
    print("Inside the function: ", car_speeds_dictionary)
change_dictionary(car_speeds_dictionary)
print()
print("Outside the function: ", car_speeds_dictionary)
# Out:
# Inside the function:  {'Camry': 200, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}
#
# Outside the function:  {'Camry': 200, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}

# %%
car_speeds_dictionary
# Out:
# {'Camry': 200, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}

# %% [markdown]
# **Look at the code from line 19 thru line 30 - within the function if the list element is modified or a new element is added, it impacts the original global var as well, in this case the "car_speeds_dictionary". But within the function, if a new dict is defined, it will have an impact only until the func ends. The global var will not be impacted.**
#
# **this is the diff between argument passing by reference vs arg passing by value**

# %%
car_speeds_dictionary
# Out:
# {'Camry': 200, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}

# %%
def change_dictionary(some_dictionary):
    
    some_dictionary["Camry"] = 140
    
    print("Inside the function: ", some_dictionary)

# %%
change_dictionary(car_speeds_dictionary)

car_speeds_dictionary
# Out:
# Inside the function:  {'Camry': 140, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}
# {'Camry': 140, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}

# %%
def change_dictionary(some_dictionary):
    
    del some_dictionary["Camry"]
    
    print("Inside the function: ", some_dictionary)

# %%
change_dictionary(car_speeds_dictionary)

car_speeds_dictionary
# Out:
# Inside the function:  {'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}
# {'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}

# %% [markdown]
# ##Objectives
# recall what it means to pass arguments by reference
# [Video description begins] Topic title: Argument Passing by Reference. Your host for this session is Janani Ravi. [Video description ends]
#
# Whatever you've studied about passing arguments into a function so far might lead you to believe that any changes that you make to an argument within a function will not be reflected outside that function.
#
# [Video description begins] A Jupyter notebook titled ArgumentPassingByReference is displayed on the screen. It has a menu bar with the following options: File, Edit, View, etc. A tool bar is present with the following buttons: Save, add, cut, run, etc. A set of code cells is present in the notebook. [Video description ends]
#
# Well, that would be wrong because there are certain nuances associated with complex data types as we shall see now, where we'll discuss argument passing by reference. Let's work with our fruits example here. Here is a list of fruits, Apple, Grapes, Mango, and Bananas.
#
# [Video description begins] The following code appears in code cell 1: fruits_list = ["Apple", "Grapes", "Mango", "Bananas"]. [Video description ends]
#
# I'm going to define a function called change_list, and this time I'm going to change the list in a slightly different way.
#
# [Video description begins] Six code lines appear in code cell 2. Line 1 is: def change_list (fruits_list):. [Video description ends]
#
# The input argument to the change_list function is fruits_list. And observe that this time I don't reassign this variable to a new list, instead, I'm updating the first element at index 0 of this fruits_list. I'm setting the first element to be Kiwi.
#
# [Video description begins] Line 2 is: fruits_list[0]= "Kiwi". [Video description ends]
#
# After making this change, I'm printing out the fruits_list within the function.
#
# [Video description begins] Line 3 is: print ("Inside the function: ", fruits_list). [Video description ends]
#
# And then I print out the fruits_list outside the function after invoking the function as well.
#
# [Video description begins] Line 4 is: change_list (fruits_list). Line 5 is: print (). Line 6 is: print ("Outside the function: ", fruits_list). [Video description ends]
#
# Now if you execute this bit of code, you'll see the difference. Observe that the fruits_list inside the function contains Kiwi as the first element. But outside the function, our original fruits_list global variable has also been updated.
#
# [Video description begins] Two lines of output appear. Line 1 is: Inside the function: ['Kiwi', 'Grapes', 'Mango', 'Bananas']. Line 2 is: Outside the function: ['Kiwi', 'Grapes', 'Mango', 'Bananas']. [Video description ends]
#
# The first element in the fruits_list outside the function is also Kiwi. So what's the difference here? Why did the fruits_list, which is declared outside the function, also change? That's because we accept it as an input into the change_list function, a complex data type, and we modified the actual contents of the list. We just didn't reassign the list, we changed the contents of the list, which is why the change was reflected in the original fruits_list, the global variable as well.
#
# [Video description begins] He points to line 2 in code cell 2. [Video description ends]
#
# This proves that when we use the fruits_ list variable inside the function, it refers to the same list as the list outside the function. Now let's say inside the function we had done something like this, fruits_list is equal to a new list with just Kiwi within it. This is reassigning the fruits_list inside the function. The original list remains unchanged and it's located somewhere in memory.
#
# [Video description begins] He highlights code cell 1. [Video description ends]
#
# What we are doing here in this change_list function is modifying the list itself. There is just one list somewhere in memory, and both of the variables inside the function as well as outside the function reference the same list. This might seem a little confusing, let's try this once again. I'm going to reinitialize the fruits_list in the global scope outside the function to be Apple and Grapes.
#
# [Video description begins] Line 3 is: fruits_list = ["Apple", "Grapes"]. [Video description ends]
#
# I'm now going to invoke the change_list function. Observe that the change_list reassigns the first element in the fruits_list to a Kiwi.
#
# [Video description begins] Line 4 is: change_list (fruits_list). [Video description ends]
#
# So when we print out this fruits_list, inside the function, you can see that it's Kiwi and Grapes.
#
# [Video description begins] Its output is: Inside the function: ['Kiwi', 'Grapes']. [Video description ends]
#
# Now if you print out this fruits_list now outside the function, you'll see that the change is reflected here as well.
#
# [Video description begins] The following code appears in code cell 5: fruits_list. Its output is: ['Kiwi', 'Grapes']. A screenshot of code cell 2 appears. [Video description ends]
#
# This is because the way the change was made. Within the change_list function, we change the actual contents of the list and this affects the list in memory. And there is just one version of the list stored in memory, referenced by the fruits_list variable inside the function and the fruits_list global variable as well. Let's take a look at another example here, the fruits_list we've initialized to Apple, Grapes, Mango, and Bananas.
#
# [Video description begins] Seven code lines appear in code cell 6. Line 1 is: fruits_list = ["Apple", "Grapes", "Mango", "Bananas"]. [Video description ends]
#
# The change_list function takes as an input argument the fruits_list and appends Kiwi to the fruits_list.
#
# [Video description begins] Line 2 is: def change_list (fruits_list):. Line 3 is: fruits_list.append= ("Kiwi"). [Video description ends]
#
# This append operation is performed by calling fruits_list.append("Kiwi"). And then we print out the fruits_list inside the function and outside the function as well.
#
# [Video description begins] Line 4 is: print ("Inside the function: ", fruits_list). Line 7 is: print ("Outside the function: ", fruits_list). [Video description ends]
#
# And once again, you'll see that both inside the function and outside the function, the Kiwi fruit has been appended to the list. There is just one list in memory and both of our variables. Whether it is the fruits_list global variable or the fruits_list local variable inside the function, both reference the same list in memory. So when you change the contents of that list by either using index values, the append operation, or a remove operation, the list contents are updated and the changes are reflected in the list.
#
# [Video description begins] Two lines of output appear. Line 1 is: Inside the function: ['Apple', 'Grapes', 'Mango', 'Bananas','Kiwi']. Line 2 is: Outside the function: ['Apple', 'Grapes', 'Mango', 'Bananas','Kiwi']. [Video description ends]
#
# Let's see another example of this. Here is our fruits_list once again, the original list is Apple, Grapes, Mango, and Bananas.
#
# [Video description begins] Seven code lines appear in code cell 7. Line 1 is: fruits_list = ["Apple", "Grapes", "Mango", "Bananas"]. [Video description ends]
#
# Within the change_list function we're going to remove the Apple fruit.
#
# [Video description begins] Line 3 is: fruits_list.remove ("Apple"). [Video description ends]
#
# Then we print out the fruits_list inside the function as well as outside the function.
#
# [Video description begins] Line 4 is: print ("Inside the function: ", fruits_list). Line 7 is: print ("Outside the function: ", fruits_list). [Video description ends]
#
# Because both of the variables local as well as global reference the same fruits_list in memory, the change is reflected inside the function as well as outside the function.
#
# [Video description begins] Two lines of output appear. Line 1 is: Inside the function: [ 'Grapes', 'Mango', 'Bananas']. Line 2 is: Outside the function: [ 'Grapes', 'Mango', 'Bananas']. [Video description ends]
#
# This demonstrates that when we work with complex data types, the argument passing is by reference. So reassigning a variable will not affect the original list, but changing the list itself will. One last example using a list before we move on to a dictionary here is our fruit_list. The original list has Apples, Grapes, Mangoes, and Bananas.
#
# [Video description begins] Five code lines appear in code cell 8. Line 1 is: fruits_list = ["Apple", "Grapes", "Mango", "Bananas"]. [Video description ends]
#
# And within the sort_items_and_remove_last function, we sort the items in the list and then go ahead and remove the last item by calling the pop function, so my_list.sort, my_list.pop.
#
# [Video description begins] Line 2 is: def sort_items_and_remove_last(my_list):. Line 3 is: my_list.sort(). Line 4 is: my_list.pop(). [Video description ends]
#
# Observe here that the name of the original global variable is fruits_list, whereas the variable of our input argument is called my_list. So within the function, we are performing my_list.sort and my_list.pop, then we print out the contents of the list within the function.
#
# [Video description begins] Line 5 is: print ("Inside the function", my_list). [Video description ends]
#
# I'm now going to go ahead and invoke this function on our fruits_list, sort_items_and_remove_last. The input argument is the fruits_list that we had set up earlier.
#
# [Video description begins] The following code appears in code cell 9: sort_items_and_remove_last(fruits_list). [Video description ends]
#
# Inside the function, you can see that the list is Apple, Bananas, Grapes. It's now sorted in the ascending order of fruits and the last fruit has been removed, the last fruit was Mango.
#
# [Video description begins] Its output is: Inside the function['Apple', 'Bananas', 'Grapes']. [Video description ends]
#
# Now the question is, the variable names are different within the function and outside the function, is the original fruits_list also affected? And the answer is yes, it doesn't matter what the name of the variable is. Both variables, whether it's outside the function or inside the function, reference the same list in memory. So when you actually modify the list contents, the changes are reflected both inside the function as well as outside the function.
#
# [Video description begins] The following code appears in code cell 10: fruits_list. Its output is: ['Apple', 'Bananas','Grapes']. [Video description ends]
#
# This proves to us that the contents of a complex data type, such as a list, can be changed from within a function, and the same is true for dictionaries as well.
#
# [Video description begins] Six code lines appear in code cell 11. Line 1 is: car_speeds_dictionary = {. Line 2 is: "Camry": 120,. Line 3 is: "Accord": 130,. Line 4 is: "Cayenne": 250,. Line 5 is: "Mini Cooper": 100. Line 6 is: }. [Video description ends]
#
# Tuples are not mutable, so we'll ignore tuples for now. Here I've set up the car_speeds_dictionary that we've seen before, which contains the speeds of four different cars. I'm now going to define a function called change_dictionary, which adds a new key value pair to this dictionary.
#
# [Video description begins] Three code lines appear in code cell 12. Line 1 is: def change_dictionary (car_speeds_dictionary):. [Video description ends]
#
# I'm going to add in the Mustang with a speed of 200 miles per hour, and we'll print out the contents of this dictionary inside the function.
#
# [Video description begins] Line 2 is: car_speeds_dictionary ["Mustang"]= 200. [Video description ends]
#
# [Video description begins] Line 3 is: print ("Inside the function:", car_speeds_dictionary). [Video description ends]
#
# Let's go ahead and invoke the change_dictionary function and pass in the car_speeds_dictionary. And you can see that inside the function, the key value pair for the Mustang is available and has been added to the dictionary.
#
# [Video description begins] The following code appears in code cell 13: change_dictionary (car_speeds_dictionary). Its output is: Inside the function:{'Camry': 120,'Accord': 130,'Cayenne': 250,'Mini Cooper': 100,'Mustang': 200}. [Video description ends]
#
# And if you check out the contents of the car_speeds_dictionary outside the function, you can see that the Mustang is present here as well.
#
# [Video description begins] The following code appears in code cell 14: car_speeds_dictionary. Its output is: {'Camry': 120, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100,'Mustang': 200}. [Video description ends]
#
# So when you change the contents of a dictionary from within a function, the dictionary contents in memory is changed. And whether you access the dictionary from within a function or outside the function, the change is reflected. Earlier, within the function, if you reassign the local variable to a brand-new dictionary, that doesn't affect the original dictionary. But if you change the contents of the original dictionary parsed in, the change is reflected everywhere. Let's see another example, here we have the change_dictionary function once again.
#
# [Video description begins] Three code lines appear in code cell 15. Line 1 is: def change_dictionary (some_dictionary):. [Video description ends]
#
# And I have updated the value associated with the Camry to be 140 miles per hour.
#
# [Video description begins] Line 2 is: some_dictionary ["Camry"] = 140. [Video description ends]
#
# Let's assume this is the speed of the latest Camry and we print out the value of this dictionary within the function.
#
# [Video description begins] Line 3 is: print ("Inside the function:", some_dictionary). [Video description ends]
#
# Observe that within this change_dictionary function, the input argument is called some_dictionary. Our original dictionary was called car_speeds_dictionary, so the name of the input argument is different.
#
# [Video description begins] A screenshot of code cell 11 appears. [Video description ends]
#
# Now, I'm going to go ahead and invoke the change_dictionary function and pass in the car_speeds_dictionary.
#
# [Video description begins] Two code lines appear in code cell 16. Line 1 is: change_dictionary (car_speeds_dictionary). Line 2 is: car_speeds_dictionary. [Video description ends]
#
# And when you print out the car_speeds_dictionary, you can see that the Camry has a speed of 140 miles per hour.
#
# [Video description begins] She highlights the following part of the output: {'Camry': 140, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100,'Mustang': 200}. [Video description ends]
#
# Originally, the Camry was at a 120 miles per hour. Our change_dictionary function updated the speed associated with the Camry. And this update is reflected in the original global variable car_speeds_dictionary as well. Because both car_speeds_dictionary and the dictionary refer to, within the change dictionary function, refer to the same location in memory. The fact that we refer to the dictionary as some_dictionary within the function and car_speeds_dictionary outside the function is irrelevant. The dictionary contents are the same. Let's take a look at one last example here. I have the change dictionary function where I delete the key for the Camry.
#
# [Video description begins] Three code lines appear in code cell 17. Line 1 is: def change_dictionary (some_dictionary):. Line 2 is: del some_dictionary ["Camry"]. Line 3 is: print ("Inside the function:", some_dictionary). [Video description ends]
#
# I'm going to call change_dictionary on our car_speeds_dictionary and print out the contents of the car_speeds_dictionary after we've invoked the function.
#
# [Video description begins] Two code lines appear in code cell 18. Line 1 is: change_dictionary (car_speeds_dictionary). Line 2 is: car_speeds_dictionary. [Video description ends]
#
# And you can see that inside the function as well as outside the function, the Camry is no longer present in our dictionary. Changes made within a function are reflected in our dictionary contents outside the function as well.
#
# [Video description begins] Two lines of output appear. Line 1 is: Inside the function: {'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100,'Mustang': 200}. Line 2 is: {'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100,'Mustang': 200}. [Video description ends]
