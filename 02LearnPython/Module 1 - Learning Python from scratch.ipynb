# %%
# !python --version
# Out:
# Python 3.9.7

# %% [markdown]
# # Calculate the power of

# %%
t = [1,2,3,4,5,6]

for i in t:
    print(i+1)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
while True:
    t = t *20
    print(t)
    if t > 1000:
        break

# %%
2**4
# Out:
# 16

# %% [markdown]
# # Normal division results in floating numbers always

# %%
10/5
# Out:
# 2.0

# %% [markdown]
# # Integer part of the division - only quotient

# %%
11//5
# Out:
# 2

# %% [markdown]
# # Remainder

# %%
10%5
# Out:
# 0

# %%
50%4
# Out:
# 2

# %%
12%5
# Out:
# 2

# %%
'hello  ram!' *3
# Out:
# 'hello  ram!hello  ram!hello  ram!'

# %%
'hello ram!' + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_23152/1524625696.py in <module>
# ----> 1 'hello ram!' + 3
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Built-in functions in Python: Functions are a reusable bits of code

# %%
'hello world!'
# Out:
# 'hello world!'

# %%
print('hello world!')
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
print(hello world!)
# Out:
#   File "C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_23152/576362961.py", line 1
#     print(hello world!)
#                 ^
# SyntaxError: invalid syntax

# %%
print "hello world!"
# Out:
#   File "C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_23152/1722370279.py", line 1
#     print "hello world!"
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("hello world!")?

# %%
len("hello world!")
# Out:
# 12

# %%
print(4+5)
# Out:
# 9

# %%
4+5
# Out:
# 9

# %%
abs(-17)
# Out:
# 17

# %%
abs(17)
# Out:
# 17

# %%
type(17.5)
# Out:
# float

# %%
type(1)
# Out:
# int

# %%
type(dsadsa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-064367489a56> in <module>
# ----> 1 type(dsadsa)
#
# NameError: name 'dsadsa' is not defined

# %%
type("dsaa")
# Out:
# str

# %%
type("12")
# Out:
# str

# %%
round(17.7)
# Out:
# 18

# %%
round(2.2)
# Out:
# 2

# %%
round(-17.5)
# Out:
# -18

# %%
max(1,3,4,5,6)
# Out:
# 6

# %%
min(-1,0)
# Out:
# -1

# %% [markdown]
# # Introducing variables to store values

# %%
salary = 24000

# %%
salary
# Out:
# 24000

# %%
house_Rent = 1000

# %%
food_exp= 500

# %%
tot_exp = house_Rent+food_exp

# %%
tot_exp
# Out:
# 1500

# %%
house_Rent
# Out:
# 1000

# %%
savings = salary - tot_exp

# %%
savings
# Out:
# 22500

# %%
print("My savings in a year is:", savings)
# Out:
# My savings in a year is: 22500

# %%
tot_savings = savings*12

# %%
print(tot_savings)
# Out:
# 270000

# %%
"day" + "light"
# Out:
# 'daylight'

# %%
print("day" + "light")
# Out:
# daylight

# %%
num_1=2
num_2="2"

# %%
num_1+num_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-2ac723b39362> in <module>
# ----> 1 num_1+num_2
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
type(num_1)
# Out:
# int

# %%
type(num_2)
# Out:
# str

# %% [markdown]
# Boolean values : True / False

# %%
x= True
y= False

# %%
print('x and y is:',x and y)
# Out:
# x and y is: False

# %%
print('x or y is:',x or y)
# Out:
# x or y is: True

# %%
print('not x is:',not x)
# Out:
# not x is: False

# %%
print('not y is:',not y)
# Out:
# not y is: True

# %%
x = awesome
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-a5d5ea197e65> in <module>
# ----> 1 x = awesome
#
# NameError: name 'awesome' is not defined

# %%
x = "awesome"

# %%
x
# Out:
# 'awesome'

# %%
print("Python is",x)
# Out:
# Python is awesome

# %%
x = "Python is"
y = " awesome"

# %%
z = x+ y

# %%
print(z)
# Out:
# Python is awesome

# %%
a = z * 4

# %%
a
# Out:
# 'Python is awesomePython is awesomePython is awesomePython is awesome'

# %%
print(a)
# Out:
# Python is awesomePython is awesomePython is awesomePython is awesome

# %%
len(x)
# Out:
# 9

# %%
len(z)
# Out:
# 17

# %%
print(z)
# Out:
# Python is awesome

# %%
print("z")
# Out:
# z

# %%
x=y=z="python"

print(x)
print(y)
print(z)
# Out:
# python
# python
# python

# %%
b=x+y
b
# Out:
# 'pythonpython'

# %%
print(b)
# Out:
# pythonpython

# %%
c=x*4

# %%
c
# Out:
# 'pythonpythonpythonpython'

# %% [markdown]
# Comparison operators

# %%
x=y==z

print(x)
# Out:
# True

# %%
a,b,c = 5,3.2,"Hello"

print(a)
print(b)
print(c)
# Out:
# 5
# 3.2
# Hello

# %%
color_a="Red"
color_b='blue'

print(color_a,color_b)
# Out:
# Red blue

# %%
color_c = color_a
print(color_a,color_b,color_c)
# Out:
# Red blue Red

# %%
color_a = color_b
print(color_a,color_b,color_c)
# Out:
# blue blue Red

# %%
n1=34
n2=34.5
n3=100

# %%
s1="Hello"
s2="World"

# %%
total_n=n1+n2+n3

# %%
total_n
# Out:
# 168.5

# %%
n1=n1+1
n1
# Out:
# 35

# %%
n2=n2+10
n2
# Out:
# 44.5

# %%
n3=n3-50
n3
# Out:
# 50

# %%
n3=n3*50
n3
# Out:
# 2500

# %%
n3=n3/50

# %%
n3
# Out:
# 50.0

# %%
n3=n3//50
n3
# Out:
# 1.0

# %%
n1
# Out:
# 35

# %%
n1 += n1+1
n1
# Out:
# 71

# %%
n2
# Out:
# 44.5

# %%
n2 +=10
n2
# Out:
# 54.5

# %%
n3
# Out:
# 1.0

# %%
n3 *=50
n3
# Out:
# 50.0

# %%
n3 *=n3
n3
# Out:
# 2500.0

# %%
n3 /=50
n3
# Out:
# 50.0

# %%
concat_string = s1+s2
concat_string
# Out:
# 'HelloWorld'

# %%
s1 = s1 + 'Yoohoo'
s1
# Out:
# 'HelloYoohoo'

# %%
s2 = s2 + 'Yippie'
s2
# Out:
# 'WorldYippie'

# %%
new_s1 = s1
new_s1
# Out:
# 'HelloYoohoo'

# %%
s1= 'some other value'
s1
# Out:
# 'some other value'

# %%
new_s1
# Out:
# 'HelloYoohoo'

# %%
some_n = n3
some_n
# Out:
# 50.0

# %%
n3 *=1000
n3
# Out:
# 50000.0

# %%
some_n
# Out:
# 50.0

# %%
x=5
y=6

# %%
x==y
# Out:
# False

# %%
x+=1
x
# Out:
# 6

# %%
x==y
# Out:
# True

# %% [markdown]
# Built in data types in Python

# %%
type(23)
# Out:
# int

# %%
type(25.5)
# Out:
# float

# %%
x=25
print("data type of",x, "is",type(x))
# Out:
# data type of 25 is <class 'int'>

# %%
y=8.2
print("data type of",y, "is",type(y))
# Out:
# data type of 8.2 is <class 'float'>

# %%
z=5j
print("data type of",z, "is",type(z))
# Out:
# data type of 5j is <class 'complex'>

# %%
print(5j*5j)
# Out:
# (-25+0j)

# %%
boolean_value=True
type(boolean_value)
# Out:
# bool

# %%
str_value ="commando"
type(str_value)
# Out:
# str

# %% [markdown]
# Binary values in Python --should always have 0b

# %%
print(0b111)
# Out:
# 7

# %%
value=0b101
value
# Out:
# 5

# %%
type(0b101)
# Out:
# int

# %% [markdown]
# Creating Single line and multi line strings

# %%
print('Hello')
# Out:
# Hello

# %%
print("Hello")
# Out:
# Hello

# %%
print("python" + ' is' + """ awesome""")
# Out:
# python is awesome

# %%
print("python" , 'is' , """awesome""")
# Out:
# python is awesome

# %%
print('python '*3)
# Out:
# python python python

# %%
print('python ' -3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_23152/173680912.py in <module>
# ----> 1 print('python ' -3)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
question ="What's for lunch?"
answer=input()

#print("You had",answer,"!", "That sounds delicious")
print("You had " + answer +"!"+ "That sounds delicious")
# Out:
# jhkj
# You had jhkj!That sounds delicious

# %%
print('I'm learning Python')
# Out:
#   File "C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_23152/2155390535.py", line 1
#     print('I'm learning Python')
#              ^
# SyntaxError: invalid syntax

# %%
print("I'm learning Python")
# Out:
# I'm learning Python

# %%
print('John said, "Hello there"')
# Out:
# John said, "Hello there"

# %% [markdown]
# #Escape Characters

# %%
print('I'm learning Python')
# Out:
#   File "C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_23152/2155390535.py", line 1
#     print('I'm learning Python')
#              ^
# SyntaxError: invalid syntax

# %%
print('I\'m learning Python')
# Out:
# I'm learning Python

# %%
print("John said \"Hello there!\"")
# Out:
# John said "Hello there!"

# %%
print('I\'m learning "python"')
# Out:
# I'm learning "python"

# %%
print("Hello John! \nHow are you?")
# Out:
# Hello John!
# How are you?

# %%
print("""I'm a tripled quote string""")
# Out:
# I'm a tripled quote string

# %%
print('''this is a very long
sentence''')
# Out:
# this is a very long
# sentence

# %%
print("""this is a very long
sentence""")
# Out:
# this is a very long
# sentence

# %%
print("this is a very long 
sentence")
# Out:
#   File "C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_23152/2709956195.py", line 1
#     print("this is a very long
#                                ^
# SyntaxError: EOL while scanning string literal

# %%
print("""this is a very long
sentence""")
# Out:
# this is a very long
# sentence

# %% [markdown]
# Formatting Operations with Strings

# %%
my_var ='barks'

print('my dog',my_var,'!')
# Out:
# my dog barks !

# %%
print(f'my dog {my_var}!')
# Out:
# my dog barks!

# %%
print('my dog {my_var}!')
# Out:
# my dog {my_var}!

# %%
print(f'''my dog {my_var}!''')
# Out:
# my dog barks!

# %%
print('my dog {}!'.format(my_var))
# Out:
# my dog barks!

# %% [markdown]
# Tab space     \t

# %%
print("John asked \t 'How are you?'")
# Out:
# John asked 	 'How are you?'

# %%
print("HEllo \t World")
# Out:
# HEllo 	 World

# %%
print('C:\\users\\test')
# Out:
# C:\users\test

# %%
print('C:\users\test')
# Out:
#   File "C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_23152/4127575791.py", line 1
#     print('C:\users\test')
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \uXXXX escape

# %% [markdown]
# the first backslash will interpret the second backslash literally

# %%
num_x=6-4
num_x
# Out:
# 2

# %%
13/5
# Out:
# 2.6

# %%
13//5
# Out:
# 2

# %%
13%5
# Out:
# 3

# %%
20%6
# Out:
# 2

# %%
20//6
# Out:
# 3

# %%
20%6
# Out:
# 2
