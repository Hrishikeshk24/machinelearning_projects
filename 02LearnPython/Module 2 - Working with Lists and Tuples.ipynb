# %% [markdown]
# Complex data type that we use in Python is Python List. It is an ordered collection of elements and these elements are specified in square brackets. So an emppty list in Python is simply two sqaure brackets with nothing in between.
# List can contain any kind of elements and elements can be of any data type.

# %%
empty_list=[]

# %%
empty_list
# Out:
# []

# %%
list_str=['bmw','mazda','hyundai']

# %%
list_str
# Out:
# ['bmw', 'mazda', 'hyundai']

# %%
type(list_str)
# Out:
# list

# %%
list_int=[1,2,3,4,5]
list_int
# Out:
# [1, 2, 3, 4, 5]

# %%
list_float=[1.3,3.3,5.6]
list_float
# Out:
# [1.3, 3.3, 5.6]

# %%
list_bool=[True,False]
list_bool
# Out:
# [True, False]

# %% [markdown]
# List can contain Duplicate values. Ordering of elements in the list is significant.
# elements of diff data types can belong to the same List

# %%
mixed_list=['hello', 1, 2.3, True]
mixed_list
# Out:
# ['hello', 1, 2.3, True]

# %% [markdown]
# List indices start from 0.

# %%
print(mixed_list[0])
# Out:
# hello

# %%
print(mixed_list[1])
# Out:
# 1

# %%
print(mixed_list[3])
# Out:
# True

# %%
print(mixed_list[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_9480/738183622.py in <module>
# ----> 1 print(mixed_list[4])
#
# IndexError: list index out of range

# %%
len(mixed_list)
# Out:
# 4

# %%
print(mixed_list[len(mixed_list)-1])
# Out:
# True

# %%
car_list=['bmw','hyundai','audi','benz']

# %%
print(car_list[-1])
# Out:
# benz

# %%
print(car_list[-2])
# Out:
# audi

# %%
print(car_list[-3])
# Out:
# hyundai

# %%
print(car_list[-4])
# Out:
# bmw

# %%
print(car_list[-5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/1726622507.py in <module>
# ----> 1 print(car_list[-5])
#
# IndexError: list index out of range

# %%
car_list[-2]
# Out:
# 'audi'

# %%
car_list
# Out:
# ['bmw', 'hyundai', 'audi', 'benz']

# %%
car_list[3]='mazda'

# %%
car_list
# Out:
# ['bmw', 'hyundai', 'audi', 'mazda']

# %%
car_list[1]='santro'
car_list
# Out:
# ['bmw', 'santro', 'audi', 'mazda']

# %% [markdown]
# # Performing simple List operations

# %%
car_list
# Out:
# ['bmw', 'santro', 'audi', 'mazda']

# %%
car_list[4]='benz'
car_list
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/1253904580.py in <module>
# ----> 1 car_list[4]='benz'
#       2 car_list
#
# IndexError: list assignment index out of range

# %%
car_list.append('benz')
car_list
# Out:
# ['bmw', 'santro', 'audi', 'mazda', 'benz']

# %% [markdown]
# append method can add just one element at a time

# %%
car_list.append('Kia','Toyota')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/2949909040.py in <module>
# ----> 1 car_list.append('Kia','Toyota')
#
# TypeError: list.append() takes exactly one argument (2 given)

# %% [markdown]
# if you want to insert an element at a specific index position in the list, use insert function on a list

# %%
car_list.insert(1,'xing')
car_list
# Out:
# ['bmw', 'xing', 'santro', 'audi', 'mazda', 'benz']

# %%
car_list.insert(1,'xing')
car_list
# Out:
# ['bmw', 'xing', 'xing', 'santro', 'audi', 'mazda', 'benz']

# %%
car_list.insert(7,'Punto')
car_list
# Out:
# ['bmw', 'xing', 'xing', 'santro', 'audi', 'mazda', 'benz', 'Punto']

# %% [markdown]
#  if you want to multiple elements to th elist, use extend function

# %%
car_list.extend(['kia Optima','Kia Soul'])
car_list
# Out:
# ['bmw',
#  'xing',
#  'xing',
#  'santro',
#  'audi',
#  'mazda',
#  'benz',
#  'Punto',
#  'kia Optima',
#  'Kia Soul']

# %%
car_list2=['Ferrari', 'Maserati', 'Mustang']

# %%
Complete_list = car_list + car_list2
Complete_list
# Out:
# ['bmw',
#  'xing',
#  'xing',
#  'santro',
#  'audi',
#  'mazda',
#  'benz',
#  'Punto',
#  'kia Optima',
#  'Kia Soul',
#  'Ferrari',
#  'Maserati',
#  'Mustang']

# %%
len(Complete_list)
# Out:
# 13

# %%
#Index function

# %%
Complete_list.index('bmw')
# Out:
# 0

# %%
Complete_list.index('Ferrari')
# Out:
# 10

# %%
#Lists also support remove function

# %%
Complete_list.remove('Maserati')
Complete_list
# Out:
# ['bmw',
#  'xing',
#  'xing',
#  'santro',
#  'audi',
#  'mazda',
#  'benz',
#  'Punto',
#  'kia Optima',
#  'Kia Soul',
#  'Ferrari',
#  'Mustang']

# %%
len(Complete_list)
# Out:
# 12

# %%
Complete_list.index('Maserati')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/767145678.py in <module>
# ----> 1 Complete_list.index('Maserati')
#
# ValueError: 'Maserati' is not in list

# %% [markdown]
# # Performing useful list operations

# %%
Complete_list +=['Chevy','Sierra']
Complete_list
# Out:
# ['bmw',
#  'xing',
#  'xing',
#  'santro',
#  'audi',
#  'mazda',
#  'benz',
#  'Punto',
#  'kia Optima',
#  'Kia Soul',
#  'Ferrari',
#  'Mustang',
#  'Chevy',
#  'Sierra']

# %%
len(Complete_list)
# Out:
# 14

# %%
#Sort function

# %%
Complete_list.sort()

# %%
Complete_list
# Out:
# ['Chevy',
#  'Ferrari',
#  'Kia Soul',
#  'Mustang',
#  'Punto',
#  'Sierra',
#  'audi',
#  'benz',
#  'bmw',
#  'kia Optima',
#  'mazda',
#  'santro',
#  'xing',
#  'xing']

# %%
Complete_list.reverse()
Complete_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'Chevy']

# %%
#pop function - removes the last element from the list everytime you execute.

# %%
Complete_list.pop()
Complete_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari']

# %%
#count function

# %%
Complete_list.append('bmw')

# %%
Complete_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw']

# %%
Complete_list.count('bmw')
# Out:
# 2

# %%
Complete_list.count('Ferrari')
# Out:
# 1

# %%
#The presence of duplicate elements is what makes a Python list different from the Python set. 
#Observe that the duplicates Xing and bmw are removed. Observe that it is enclsed in curly brackets.

# %%
set(Complete_list)
# Out:
# {'Ferrari',
#  'Kia Soul',
#  'Mustang',
#  'Punto',
#  'Sierra',
#  'audi',
#  'benz',
#  'bmw',
#  'kia Optima',
#  'mazda',
#  'santro',
#  'xing'}

# %%
len(set(Complete_list))
# Out:
# 12

# %%
len(Complete_list)
# Out:
# 14

# %%
Complete_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw']

# %%
print(car_list)
# Out:
# ['bmw', 'xing', 'xing', 'santro', 'audi', 'mazda', 'benz', 'Punto', 'kia Optima', 'Kia Soul']

# %%
#to remove all elements from the list in one go, use Clear function

# %%
car_list.clear()
car_list
# Out:
# []

# %%
car_list
# Out:
# []

# %%
Complete_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw']

# %%
#To make a copy of the list, use copy function. This is a Deep copy. 
#Changes we make on the list will not affect the other list because it is a deep copy.

# %%
new_list=Complete_list.copy()

# %%
new_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw']

# %%
del(Complete_list)

# %%
Complete_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/123556075.py in <module>
# ----> 1 Complete_list
#
# NameError: name 'Complete_list' is not defined

# %%
new_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw']

# %%
Complete_list=new_list.copy()

# %%
Complete_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw']

# %%
#we can also create a Shallow copy of the list using an assignment operator. 
#Both new_list and another_list refer to the SAME LIST.
#Whatever changes we make in one list will be reflected in the other list as wel

# %%
another_list=new_list

# %%
another_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw']

# %%
new_list.append('Toyoto')

# %%
new_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw',
#  'Toyoto']

# %%
another_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw',
#  'Toyoto']

# %%
another_list.remove('Toyoto')

# %%
another_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw']

# %%
new_list
# Out:
# ['xing',
#  'xing',
#  'santro',
#  'mazda',
#  'kia Optima',
#  'bmw',
#  'benz',
#  'audi',
#  'Sierra',
#  'Punto',
#  'Mustang',
#  'Kia Soul',
#  'Ferrari',
#  'bmw']

# %% [markdown]
# Using built-in functions with Lists

# %%
list_num=[20,70,80,60,10]
list_num
# Out:
# [20, 70, 80, 60, 10]

# %%
max(list_num)
# Out:
# 80

# %%
min(list_num)
# Out:
# 10

# %%
len(list_num)
# Out:
# 5

# %%
list_num.sort()

# %%
list_num
# Out:
# [10, 20, 60, 70, 80]

# %%
list_num.append(26)

# %%
list_num
# Out:
# [10, 20, 60, 70, 80, 26]

# %%
list_num.sort()
list_num
# Out:
# [10, 20, 26, 60, 70, 80]

# %%
sorted_list_num=sorted(list_num)
sorted_list_num
# Out:
# [10, 20, 26, 60, 70, 80]

# %%
test=list_num.sort()

# %%
test

# %%
test=sorted(list_num)
test
# Out:
# [10, 20, 26, 60, 70, 80]

# %%
list_num
# Out:
# [10, 20, 26, 60, 70, 80]

# %%
sum(list_num)
# Out:
# 266

# %%
list_num = list_num * 3
list_num
# Out:
# [10, 20, 26, 60, 70, 80, 10, 20, 26, 60, 70, 80, 10, 20, 26, 60, 70, 80]

# %%
list_num *=2
list_num
# Out:
# [10,
#  20,
#  26,
#  60,
#  70,
#  80,
#  10,
#  20,
#  26,
#  60,
#  70,
#  80,
#  10,
#  20,
#  26,
#  60,
#  70,
#  80,
#  10,
#  20,
#  26,
#  60,
#  70,
#  80,
#  10,
#  20,
#  26,
#  60,
#  70,
#  80,
#  10,
#  20,
#  26,
#  60,
#  70,
#  80]

# %%
list_num *=2.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/2516568509.py in <module>
# ----> 1 list_num *=2.0
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# 0 is considered the boolean value of FALSE. All values greater than 0 are considered TRUE

# %%
all([0])
# Out:
# False

# %%
all([1])
# Out:
# True

# %%
all([0,1])
# Out:
# False

# %%
all(list_num)
# Out:
# True

# %%
all([-1])
# Out:
# True

# %%
new_num_list=[]
all(new_num_list)
# Out:
# True

# %%
all([new_num_list])
# Out:
# False

# %%
any([0])
# Out:
# False

# %%
any([1])
# Out:
# True

# %%
any([0,1])
# Out:
# True

# %%
any([list_num])
# Out:
# True

# %%
any([new_num_list])
# Out:
# False

# %%
any(new_num_list)
# Out:
# False

# %%
my_boolean = True

# %%
a=my_boolean * 3.1
a
# Out:
# 3.1

# %%
my_boolean = False

# %%
b = my_boolean * 4
b
# Out:
# 0

# %%
a = "Hello"
b = "world"
c = a + b
d = print(c)
print(d)
# Out:
# Helloworld
# None

# %% [markdown]
# #### None typically arises when you assign a variable to an expression that doesn't simplify to anything. In this class, it will usually mean that there's a mistake in your code.
# #### You should never assign a variable to a print statement. You should never do something like a = print("Hi!").

# %%
my_integer = float("hello")
my_integer
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/4171076556.py in <module>
# ----> 1 my_integer = float("hello")
#       2 my_integer
#
# ValueError: could not convert string to float: 'hello'

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Performing slicing operation on lists

# %%
my_car_list = ['TC', 'BMW', 'AUDI', 'MERC']
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC']

# %%
len(my_car_list)
# Out:
# 4

# %%
my_car_list[3]
# Out:
# 'MERC'

# %%
my_car_list[2]
# Out:
# 'AUDI'

# %%
my_car_list[-2]
# Out:
# 'AUDI'

# %%
my_car_list[-4]
# Out:
# 'TC'

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC']

# %%
my_car_list.append('Mazda')

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda']

# %%
my_car_list.extend(['kia'])

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'kia', 'kia']

# %%
my_car_list.remove('kia')

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda']

# %%
my_car_list.extend(['Kia','Honda'])

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia', 'Honda']

# %%
my_car_list.remove(['Honda'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/690769584.py in <module>
# ----> 1 my_car_list.remove(['Honda'])
#
# ValueError: list.remove(x): x not in list

# %%
my_car_list.remove('Honda')

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia']

# %%
#Slicing allows us to access a range of elements from the list
#Slicing creates a deep copy of the list
#list[start_index:end_index]
#end_index is excluded always

# %%
my_car_list[0:4]
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC']

# %%
my_car_list[0:2]
# Out:
# ['TC', 'BMW']

# %%
my_car_list[0:7]
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia']

# %%
my_car_list[7:]
# Out:
# []

# %%
my_car_list[6:]
# Out:
# []

# %%
my_car_list[5:6]
# Out:
# ['Kia']

# %%
my_car_list[3:6]
# Out:
# ['MERC', 'Mazda', 'Kia']

# %%
my_car_list[3:8]
# Out:
# ['MERC', 'Mazda', 'Kia']

# %%
my_car_list[:3]
# Out:
# ['TC', 'BMW', 'AUDI']

# %%
my_car_list[3:]
# Out:
# ['MERC', 'Mazda', 'Kia']

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia']

# %%
my_car_list[2:2]
# Out:
# []

# %%
my_car_list[0:-6]
# Out:
# []

# %%
my_car_list[0:-5]
# Out:
# ['TC']

# %%
my_car_list[0:-4]
# Out:
# ['TC', 'BMW']

# %%
my_car_list[0:-3]
# Out:
# ['TC', 'BMW', 'AUDI']

# %%
my_car_list[0:-2]
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC']

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia']

# %%
my_car_list[0:-1]
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda']

# %%
my_car_list[0:0]
# Out:
# []

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia']

# %%
my_car_list[-1]
# Out:
# 'Kia'

# %%
my_car_list[-4:-1]
# Out:
# ['AUDI', 'MERC', 'Mazda']

# %%
my_car_list[-1:-4]
# Out:
# []

# %% [markdown]
# Using step size in slicing operations

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia']

# %%
#Syntax: list_name[start_index:End_index:step_size]

# %%
my_car_list[0:3:]
# Out:
# ['TC', 'BMW', 'AUDI']

# %%
my_car_list[0:3:2]
# Out:
# ['TC', 'AUDI']

# %%
my_car_list[::2]
# Out:
# ['TC', 'AUDI', 'Mazda']

# %%
my_car_list[1:4:3]
# Out:
# ['BMW']

# %%
my_car_list[2:5:2]
# Out:
# ['AUDI', 'Mazda']

# %%
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia']

# %%
my_car_list[::-1]
# Out:
# ['Kia', 'Mazda', 'MERC', 'AUDI', 'BMW', 'TC']

# %%
my_car_list.reverse()

# %%
my_car_list
# Out:
# ['Kia', 'Mazda', 'MERC', 'AUDI', 'BMW', 'TC']

# %%
my_car_list[::-1]
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia']

# %%
my_car_list
# Out:
# ['Kia', 'Mazda', 'MERC', 'AUDI', 'BMW', 'TC']

# %%
my_car_list[::-1]
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia']

# %%
my_car_list
# Out:
# ['Kia', 'Mazda', 'MERC', 'AUDI', 'BMW', 'TC']

# %%
my_car_list[2:0:-1]
# Out:
# ['MERC', 'Mazda']

# %%
my_car_list[2:1:-1]
# Out:
# ['MERC']

# %%
my_car_list[2:0:-2]
# Out:
# ['MERC']

# %%
my_car_list[7:0:-2]
# Out:
# ['TC', 'AUDI', 'Mazda']

# %%
my_car_list[-2:0:-2]
# Out:
# ['BMW', 'MERC']

# %%
my_car_list.reverse()
my_car_list
# Out:
# ['TC', 'BMW', 'AUDI', 'MERC', 'Mazda', 'Kia']

# %%
my_car_list[-2:0:-1]
# Out:
# ['Mazda', 'MERC', 'AUDI', 'BMW']

# %%
my_car_list[::-2]
# Out:
# ['Kia', 'MERC', 'BMW']

# %%
my_car_list.reverse()

# %%
my_car_list
# Out:
# ['Kia', 'Mazda', 'MERC', 'AUDI', 'BMW', 'TC']

# %%
print(my_car_list)
len(my_car_list)
# Out:
# ['Kia', 'Mazda', 'MERC', 'AUDI', 'BMW', 'TC']
# 6

# %%
my_car_list[7:-1]=['Ford','Tesla']
my_car_list
# Out:
# ['Mazda', 'AUDI', 'BMW', 'TC', 'Ford', 'Ford', 'Ford', 'Tesla']

# %%
'TC' in my_car_list
# Out:
# True

# %%
'santro' in my_car_list
# Out:
# False

# %%
my_car_list
# Out:
# ['Mazda', 'AUDI', 'BMW', 'TC', 'Ford', 'Ford', 'Ford', 'Tesla']

# %%
my_car_list.pop(1)
# Out:
# 'AUDI'

# %%
my_car_list
# Out:
# ['Mazda', 'BMW', 'TC', 'Ford', 'Ford', 'Ford', 'Tesla']

# %%
my_car_list.pop(-6)
# Out:
# 'BMW'

# %%
my_car_list
# Out:
# ['Mazda', 'TC', 'Ford', 'Ford', 'Ford', 'Tesla']

# %%
'MERC' in my_car_list
# Out:
# False

# %% [markdown]
# WORKNG WITH STRINGS AS A LIST OF CHARACTERS

# %%
print('World')
# Out:
# World

# %%
x='World'
x
# Out:
# 'World'

# %%
x[0]
# Out:
# 'W'

# %%
x(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/602412890.py in <module>
# ----> 1 x(0)
#
# TypeError: 'str' object is not callable

# %%
x[3]
# Out:
# 'l'

# %%
x[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/556858764.py in <module>
# ----> 1 x[6]
#
# IndexError: string index out of range

# %%
x[0]='B'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/1739739580.py in <module>
# ----> 1 x[0]='B'
#
# TypeError: 'str' object does not support item assignment

# %%
#Strings are immutable - Cannot update specific character in a string

# %%
a,b,c,d,e=x
print(a)
# Out:
# W

# %%
a,b,c,d,e
# Out:
# ('W', 'o', 'r', 'l', 'd')

# %%
a,b,c,d=x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/1930793449.py in <module>
# ----> 1 a,b,c,d=x
#
# ValueError: too many values to unpack (expected 4)

# %%
a,b,_,_,_=x
b
# Out:
# 'o'

# %%
print(b)
# Out:
# o

# %%
a
# Out:
# 'W'

# %%
input('How are you?: ')
# Out:
# How are you?: ok
# 'ok'

# %%
place = input('Where are you from?: ')
# Out:
# Where are you from?: mysore

# %%
place
# Out:
# 'mysore'

# %%
print(place)
# Out:
# mysore

# %%
len(place)
# Out:
# 6

# %%
place[2:4]
# Out:
# 'so'

# %%
place[:]
# Out:
# 'mysore'

# %%
place[-2:-1]
# Out:
# 'r'

# %%
place
# Out:
# 'mysore'

# %%
place[4:-4]
# Out:
# ''

# %%
place[2:6:2]
# Out:
# 'sr'

# %%
place[::3]
# Out:
# 'mo'

# %%
sub=place[:3]

# %%
sub
# Out:
# 'mys'

# %%
del sub

# %%
sub
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/35866194.py in <module>
# ----> 1 sub
#
# NameError: name 'sub' is not defined

# %% [markdown]
# INVOKING FUNCTIONS ON STRINGS

# %%
print(place.startswith('M'))
# Out:
# True

# %%
place.startswith('M')
# Out:
# True

# %%
print(place.startswith('N'))
# Out:
# False

# %%
print(place.endswith('e'))
# Out:
# True

# %%
print(place.endswith('E'))
# Out:
# False

# %%
print(place.endswith('re'))
# Out:
# True

# %%
print(place.endswith('Mysore'))
# Out:
# False

# %%
place.count('y')
# Out:
# 1

# %%
place.count('m')
# Out:
# 1

# %%
place.count('M')
# Out:
# 0

# %%
lower_place=place.lower()

# %%
place
# Out:
# 'mysore'

# %%
lower_place
# Out:
# 'mysore'

# %%
upper_place=place.upper()

# %%
upper_place
# Out:
# 'MYSORE'

# %%
upper_place.count('Y')
# Out:
# 1

# %%
upper_place ==lower_place
# Out:
# False

# %%
# '==' performs conditional check for equality
# different from assignment which uses just "="

# %%
place == upper_place
# Out:
# False

# %%
place = upper_place

# %%
place
# Out:
# 'MYSORE'

# %%
place == upper_place
# Out:
# True

# %%
place.find('M')
# Out:
# 0

# %%
place.find('E')
# Out:
# 5

# %%
place.find('YSORE')
# Out:
# 1

# %%
place.index('E')
# Out:
# 5

# %%
place.count('E')
# Out:
# 1

# %%
place.find('E')
# Out:
# 5

# %%
place
# Out:
# 'MYSORE'

# %%
place.index('e')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/3067229406.py in <module>
# ----> 1 place.index('e')
#
# ValueError: substring not found

# %%
place.find('e')
# Out:
# -1

# %%
#notice diff between find and index function above. -1 simply represents that the char is not found.
#This is the only diff between find and index.

# %%
place.index('MYSORE')
# Out:
# 0

# %%
place.index('RE')
# Out:
# 4

# %%
split_place=place.split('E')
split_place
# Out:
# ['MYSOR', '']

# %%
place.count(" ")
# Out:
# 0

# %%
place
# Out:
# 'MYSORE'

# %%
place=input('where?: ')
# Out:
# where?: mysore

# %%
place
# Out:
# 'mysore'

# %%
place.count(' ')
# Out:
# 0

# %%
split_place=place.split('e')
split_place
# Out:
# ['mysor', '']

# %%
len(split_place)
# Out:
# 2

# %%
# Reverse of split functio is join function

# %%
join_char=','
join_char.join(split_place)
# Out:
# 'mysor,'

# %%
join_char='e'
join_char.join(split_place)
# Out:
# 'mysore'

# %%
"|".join(split_place)
# Out:
# 'mysor|'

# %% [markdown]
# PERFORMING SLICING OPERATIONS ON STRINGS

# %%
my_string ='Hello Python World'
print(my_string[0:18])
# Out:
# Hello Python World

# %%
print(my_string[0:100])
# Out:
# Hello Python World

# %%
print(my_string[0:17])
# Out:
# Hello Python Worl

# %%
print(my_string[0:6])
# Out:
# Hello

# %%
print(my_string[6:18])
# Out:
# Python World

# %%
print(my_string[6:12])
# Out:
# Python

# %%
print(my_string[::2])
# Out:
# HloPto ol

# %%
print(my_string[0:18:1])
# Out:
# Hello Python World

# %%
print(my_string[0:18:2])
# Out:
# HloPto ol

# %%
print(my_string[18:0:-2])
# Out:
# drWnhy le

# %%
print(my_string[4::-1])
# Out:
# olleH

# %%
print(my_string[::-1])
# Out:
# dlroW nohtyP olleH

# %%
some_string=my_string.split()
some_string
# Out:
# ['Hello', 'Python', 'World']

# %%
some_string[0]
# Out:
# 'Hello'

# %%
some_string[1]
# Out:
# 'Python'

# %%
some_string[2]
# Out:
# 'World'

# %%
#the presence of square brackets indicates that this is a python list

# %%
my_string.upper()
# Out:
# 'HELLO PYTHON WORLD'

# %%
my_string.lower()
# Out:
# 'hello python world'

# %%
my_string
# Out:
# 'Hello Python World'

# %%
'HELLO'.isupper()
# Out:
# True

# %%
'HELLO'.islower()
# Out:
# False

# %%
my_string = 'HELLO PYTHON WORLD'
my_string
# Out:
# 'HELLO PYTHON WORLD'

# %%
my_string.lower()
# Out:
# 'hello python world'

# %% [markdown]
# # INTRODUCTION TO TUPLES

# %%
#Another complex data types in Python. These are actually classes in Python.
#Order matters.Mostly similar to lists but there are differences.
#

# %%
my_tuple=()
my_tuple
# Out:
# ()

# %%
#above is how you initialize a tuple

# %%
type(my_tuple)
# Out:
# tuple

# %%
print(type(my_tuple))
# Out:
# <class 'tuple'>

# %%
list = [1,2,3]
print(list)
# Out:
# [1, 2, 3]

# %%
list
# Out:
# [1, 2, 3]

# %%
int_tuple=(1,2,3)
print(int_tuple)
# Out:
# (1, 2, 3)

# %%
int_tuple
# Out:
# (1, 2, 3)

# %%
str_tuple=('Hello', 'World')
print(str_tuple)
# Out:
# ('Hello', 'World')

# %%
print(int_tuple, str_tuple)
# Out:
# (1, 2, 3) ('Hello', 'World')

# %%
combined_tuple = int_tuple + str_tuple
combined_tuple
# Out:
# (1, 2, 3, 'Hello', 'World')

# %%
print(combined_tuple)
# Out:
# (1, 2, 3, 'Hello', 'World')

# %%
print(str_tuple * 3)
# Out:
# ('Hello', 'World', 'Hello', 'World', 'Hello', 'World')

# %%
mixed_tuple =(1,'Hello',3.4)
print(mixed_tuple)
# Out:
# (1, 'Hello', 3.4)

# %%
my_tuple =1,'Hello',3.4
print(my_tuple)
# Out:
# (1, 'Hello', 3.4)

# %%
#note that there were no brackets while initializing
#For Lists, we call it Elements of a list and for Tuples, we call it Fields.

# %%
a,b,c=my_tuple

print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.4

# %%
nested_tuple=(1,2,3,(4,5,6))
print(nested_tuple)
# Out:
# (1, 2, 3, (4, 5, 6))

# %%
#Tuple can contain nested tuples as above and also nested lists. see below:

# %%
mixed_tuple = ("mouse", [1,2,3], (4,5,6))
print(mixed_tuple)
# Out:
# ('mouse', [1, 2, 3], (4, 5, 6))

# %%
my_tuple = ('a','e','i','o','u')
my_tuple
# Out:
# ('a', 'e', 'i', 'o', 'u')

# %%
print(my_tuple[0])
# Out:
# a

# %%
print(my_tuple[4])
# Out:
# u

# %%
print(my_tuple[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/193982065.py in <module>
# ----> 1 print(my_tuple[5])
#
# IndexError: tuple index out of range

# %%
#note the error above

# %%
mixed_tuple
# Out:
# ('mouse', [1, 2, 3], (4, 5, 6))

# %%
print(mixed_tuple[1])
# Out:
# [1, 2, 3]

# %%
print(mixed_tuple[1][0])
# Out:
# 1

# %%
#to access the particular element of the list, do as above

# %%
print(mixed_tuple[1][1])
# Out:
# 2

# %%
print(mixed_tuple[1][2])
# Out:
# 3

# %%
print(mixed_tuple[1][3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/2887013823.py in <module>
# ----> 1 print(mixed_tuple[1][3])
#
# IndexError: list index out of range

# %%
mixed_tuple
# Out:
# ('mouse', [1, 2, 3], (4, 5, 6))

# %%
nested_tuple = mixed_tuple[2]
nested_tuple
# Out:
# (4, 5, 6)

# %%
print(mixed_tuple[2][0])
# Out:
# 4

# %%
print(mixed_tuple[2][1])
# Out:
# 5

# %%
my_tuple
# Out:
# ('a', 'e', 'i', 'o', 'u')

# %%
print(my_tuple[1:])
# Out:
# ('e', 'i', 'o', 'u')

# %%
print(my_tuple[1:2])
# Out:
# ('e',)

# %%
print(my_tuple[:4])
# Out:
# ('a', 'e', 'i', 'o')

# %%
print(my_tuple[:])
# Out:
# ('a', 'e', 'i', 'o', 'u')

# %%
print(my_tuple[::2])
# Out:
# ('a', 'i', 'u')

# %%
print(my_tuple[-1])
# Out:
# u

# %%
print(my_tuple.index('a'))
# Out:
# 0

# %%
print(my_tuple.index('u'))
# Out:
# 4

# %%
print('e' in my_tuple)
# Out:
# True

# %%
'e' in my_tuple
# Out:
# True

# %%
print('d' in my_tuple)
# Out:
# False

# %%
print('t' not in my_tuple)
# Out:
# True

# %%
int_tuple
# Out:
# (1, 2, 3)

# %%
sum(int_tuple)
# Out:
# 6

# %%
list(int_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/192833679.py in <module>
# ----> 1 list(int_tuple)
#
# TypeError: 'list' object is not callable

# %%
set(int_tuple)
# Out:
# {1, 2, 3}

# %%
int_tuple=(3,3,3,3,3)

# %%
set(int_tuple)
# Out:
# {3}

# %%
# no duplicates in set

# %% [markdown]
# # Understanding Tuple Immutability

# %%
#Significant diff between lists and tuples is that tuples are immutable - once created, cannot be updated or changed in any way.
#See below example

# %%
immutable_tuple_1=(1,2,3,4)

# %%
immutable_tuple_1[0]=5
print(immutable_tuple_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/1063781148.py in <module>
# ----> 1 immutable_tuple_1[0]=5
#       2 print(immutable_tuple_1)
#
# TypeError: 'tuple' object does not support item assignment

# %%
immutable_tuple_2 = (1,2,3,(4,5,6))

# %%
print(immutable_tuple_2)
# Out:
# (1, 2, 3, (4, 5, 6))

# %%
immutable_tuple_2[0]
# Out:
# 1

# %%
immutable_tuple_2[3]
# Out:
# (4, 5, 6)

# %%
immutable_tuple_2[3][1]
# Out:
# 5

# %%
immutable_tuple_3 = (1,2,3,[4,5,6])

# %%
immutable_tuple_3
# Out:
# (1, 2, 3, [4, 5, 6])

# %%
immutable_tuple_3[3]
# Out:
# [4, 5, 6]

# %%
immutable_tuple_3[1]=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/1233485474.py in <module>
# ----> 1 immutable_tuple_3[1]=10
#
# TypeError: 'tuple' object does not support item assignment

# %%
immutable_tuple_3[3][0]=10

# %%
immutable_tuple_3
# Out:
# (1, 2, 3, [10, 5, 6])

# %%
#we cannot update tuple but can update the list that is within the tuple

# %%
my_tuple=('p','y','t','h','o','n')
my_tuple
# Out:
# ('p', 'y', 't', 'h', 'o', 'n')

# %%
del my_tuple[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/300550573.py in <module>
# ----> 1 del my_tuple[3]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
#note that we cannot delete a particular field in a tuple but you can delete the tuple as a whole. see below

# %%
del my_tuple

# %%
my_tuple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/3943104937.py in <module>
# ----> 1 my_tuple
#
# NameError: name 'my_tuple' is not defined

# %%
tuple_a=(1,2,3,4,5)
tuple_b=('a','b','c','d','e')

# %%
#zip function

# %%
zipped = zip (tuple_a,tuple_b)
print(zipped)

# %%
#we cannot tell what the structure of this obect is.
#In its simples form, we can think of the zipped data struc as the collection of tuples
# like (1,'a') (2,'b') ....

# %%
result=tuple(zipped)
print(result)
# Out:
# ((1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e'))

# %%
#very important#Zipped result converted to a complex data type - tuple, dic, set, list etc
#the result is the tuple of tuples

# %%
tuple_x, tuple_y = zip(*result)

# %%
print(tuple_x, tuple_y)
# Out:
# (1, 2, 3, 4, 5) ('a', 'b', 'c', 'd', 'e')

# %%
#zip operation is useful to bring two ordered collections together. Zip operation can alsow ork with lists.

# %%
list_a=[6,7,8,9,10]

# %%
list_b=['a','e','i','o','u']

# %%
zipped_list = zip(list_a,list_b)
print(zipped_list)

# %%
result = list(zipped_list)
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/2078921087.py in <module>
# ----> 1 result = list(zipped_list)
#       2 print(result)
#
# TypeError: 'list' object is not callable

# %%
result1 = tuple(zipped_list)
print(result1)
# Out:
# ((6, 'a'), (7, 'e'), (8, 'i'), (9, 'o'), (10, 'u'))

# %%
a= ("ram", "hris", "shru", "appa", "amma")
b= ("mysore", "Pitts", "India", "usa","ka")

# %%
x = zip(a,b)

# %%
print(x)

# %%
test=list(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/2440712738.py in <module>
# ----> 1 test=list(x)
#
# TypeError: 'list' object is not callable

# %%
print(test)
# Out:
# [10, 20, 26, 60, 70, 80]

# %%
print(x)

# %%
print(dict(x))
# Out:
# {'ram': 'mysore', 'hris': 'Pitts', 'shru': 'India', 'appa': 'usa', 'amma': 'ka'}

# %%
x=zip(a,b)

# %%
print(dict(x))
# Out:
# {'ram': 'mysore', 'hris': 'Pitts', 'shru': 'India', 'appa': 'usa', 'amma': 'ka'}

# %%
#Keys of this dictionary are all the fields from the first tuple - ram, hris etc
#Corresponding Values are all of the fields from the second tuple.

# %%
num_list =[1,2,3]
str_list = ['one', 'two', 'three']
num_tuple =('ONE', 'TWO', 'THREE', 'FOUR')
result = zip(num_list, num_tuple)

# %%
print(result)

# %%
resut_set=set(result)

# %%
print(resut_set)
# Out:
# {(1, 'ONE'), (2, 'TWO'), (3, 'THREE')}

# %%
result = zip(num_list, str_list, num_tuple)

# %%
result_set=set(result)
print(result_set)
# Out:
# {(3, 'three', 'THREE'), (2, 'two', 'TWO'), (1, 'one', 'ONE')}

# %% [markdown]
# INTRODUCING OTHER COMPLEX DATA TYPES

# %%
num_list =[1,2.5,'num',True]
print(num_list)
# Out:
# [1, 2.5, 'num', True]

# %%
#List can contain elements of different data types.

# %%
type(num_list)
# Out:
# list

# %%
type(num_list[1])
# Out:
# float

# %%
type(num_list[-1])
# Out:
# bool

# %%
type(num_list[len(num_list)-1])
# Out:
# bool

# %%
num_t = (1,2.5,'num',True)
num_t
# Out:
# (1, 2.5, 'num', True)

# %%
type(num_t)
# Out:
# tuple

# %%
type(num_t[2])
# Out:
# str

# %%
#DICTIONARIES:

# Use curly braces
# Each record is a key-value pair

# %%
my_dict={"a":2,
         "b":2.5,
         "c":20}

my_dict
# Out:
# {'a': 2, 'b': 2.5, 'c': 20}

# %%
type(my_dict)
# Out:
# dict

# %%
#set - An unordered collection of unique elements

# %%
a={5,2,3,'1',4,4}
a
# Out:
# {'1', 2, 3, 4, 5}

# %%
type(a)
# Out:
# set

# %% [markdown]
# TEST

# %%
some_str ="Hello"

# %%
some_str[::-1]
# Out:
# 'olleH'

# %%
some_str.reverse()
some_str
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/1953366331.py in <module>
# ----> 1 some_str.reverse()
#       2 some_str
#
# AttributeError: 'str' object has no attribute 'reverse'

# %%
rev = some_str.reverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/610811136.py in <module>
# ----> 1 rev = some_str.reverse()
#
# AttributeError: 'str' object has no attribute 'reverse'

# %%
some_string = "Python"
a, b, c, d,e,f = some_string

# %%
print(a)
# Out:
# P

# %%
city = 'Los Angeles'
city.find('x')
# Out:
# -1

# %%
city.index['x']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/2119924334.py in <module>
# ----> 1 city.index['x']
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
my_integer = 5
if my_integer == 5:
    
    print(True)
# Out:
# True

# %%
my_integer = 7
continue = True
if continue:
    print(my_integer)
# Out:
#   File "C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/2017986254.py", line 2
#     continue = True
#              ^
# SyntaxError: invalid syntax

# %%
int = "5"
other_int = "7"
combined_int = int + otherInt
result = int(combined_int)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HRISHI~1.HAR\AppData\Local\Temp/ipykernel_7872/498050467.py in <module>
#       1 int = "5"
#       2 other_int = "7"
# ----> 3 combined_int = int + otherInt
#       4 result = int(combined_int)
#       5 print(result)
#
# NameError: name 'otherInt' is not defined
