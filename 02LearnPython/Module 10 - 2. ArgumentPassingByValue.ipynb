# %%
salary = 1000
expense = 200

name = "James"
interest_rate = 0.04

# %%
def print_savings_details():
    
    print("Name on account: ", name)
    
    savings  = salary - expense
    print("Savings: ", savings)
    
    print("Interest rate: ", interest_rate)

# %%
print_savings_details()
# Out:
# Name on account:  James
# Savings:  800
# Interest rate:  0.04

# %%
def print_savings_details(name, salary, expense, interest_rate):
    
    print("Name on account: ", name)
    
    savings  = salary - expense
    print("Savings: ", savings)
    
    print("Interest rate: ", interest_rate)

# %%
print_savings_details(name, salary, expense, interest_rate)
# Out:
# Name on account:  James
# Savings:  800
# Interest rate:  0.04

# %%
print_savings_details("Julie", 10000, 2000, 0.02)
# Out:
# Name on account:  Julie
# Savings:  8000
# Interest rate:  0.02

# %%
def print_savings_details(name, salary, expense, interest_rate):
    
    print("Name on account: ", name)

    expense = expense + 100
    
    savings  = salary - expense
    print("Savings: ", savings)
    
    print("Interest rate: ", interest_rate)

# %%
print_savings_details(name, salary, expense, interest_rate)
# Out:
# Name on account:  James
# Savings:  700
# Interest rate:  0.04

# %%
name, salary, expense, interest_rate
# Out:
# ('James', 1000, 200, 0.04)

# %%
def print_savings_details(name, salary, expense, interest_rate):
    
    name = "Harry"
    print("Name on account: ", name)

    salary = salary * 2
    expense = expense + 100

    savings  = salary - expense
    print("Savings: ", savings)
    
    interest_rate = 0.09
    print("Interest rate: ", interest_rate)

# %%
print_savings_details(name, salary, expense, interest_rate)
# Out:
# Name on account:  Harry
# Savings:  1700
# Interest rate:  0.09

# %%
name, salary, expense, interest_rate
# Out:
# ('James', 1000, 200, 0.04)

# %%
fruits_list = ["Apple", "Grapes", "Mango", "Bananas"]

# %%
def change_list(fruits_list):
    
    fruits_list = ["Kiwi", "Strawberry"]
    
    print("Inside the function: ", fruits_list)

change_list(fruits_list)
print()
print("Outside the function: ", fruits_list)
# Out:
# Inside the function:  ['Kiwi', 'Strawberry']
#
# Outside the function:  ['Apple', 'Grapes', 'Mango', 'Bananas']

# %%
fruits_list = ["Apple", "Grapes"]

# %%
change_list(fruits_list)
# Out:
# Inside the function:  ['Kiwi', 'Strawberry']

# %%
fruits_list
# Out:
# ['Apple', 'Grapes']

# %%
fruits_tuple = ("Apple", "Grapes", "Mango", "Bananas")

# %%
def change_tuple(fruits_tuple):
    
    fruits_tuple = ("Kiwi", "Strawberry")
    
    print("Inside the function: ", fruits_tuple)

change_tuple(fruits_tuple)
print()
print("Outside the function: ", fruits_tuple)
# Out:
# Inside the function:  ('Kiwi', 'Strawberry')
#
# Outside the function:  ('Apple', 'Grapes', 'Mango', 'Bananas')

# %%
def change_tuple(fruits_tuple):
    
    fruits_tuple = "This is not even a tuple"
    
    print("Inside the function: ", fruits_tuple)

change_tuple(fruits_tuple)
print()
print("Outside the function: ", fruits_tuple)
# Out:
# Inside the function:  This is not even a tuple
#
# Outside the function:  ('Apple', 'Grapes', 'Mango', 'Bananas')

# %%
car_speeds_dictionary = {
    "Camry": 120,
    "Accord": 130,
    "Cayenne": 250,
    "Mini Cooper": 100
}

# %%
def change_dictionary(car_speeds_dictionary):
    
    car_speeds_dictionary = {
        "Mustang": 200
    }
    
    print("Inside the function: ", car_speeds_dictionary)

# %%
change_dictionary(car_speeds_dictionary)
# Out:
# Inside the function:  {'Mustang': 200}

# %%
car_speeds_dictionary
# Out:
# {'Camry': 120, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}

# %% [markdown]
# ## Objectives
# recall what it means to pass arguments by value
# [Video description begins] Topic title: Argument Passing by Value. Your host for this session is Janani Ravi. [Video description ends]
#
# When you pass input arguments while invoking a function, there are some subtle details that you need to keep in mind based on the kind of argument that you're passing in. And that's exactly what we'll study here in this demo. How we pass arguments by value.
#
# [Video description begins] A Jupyter notebook titled ArgumentPassingByValue is displayed on the screen. It has a menu bar with the following options: File, Edit, View, etc. A tool bar is present with the following buttons: Save, add, cut, run, etc. A set of code cells is present in the notebook. [Video description ends]
#
# I'm going to define and assign values to four variables here, salary, expense, name, and interest_rate.
#
# [Video description begins] Four code lines appear in code cell 1. Line 1 is: salary = 1000. Line 2 is: expense = 200. Line 3 is: name = "James". Line 4 is: interest_rate = 0.04. [Video description ends]
#
# I'm now going to define a function called print_savings_details which take in no input argument.
#
# [Video description begins] Five code lines appear in code cell 2. Line 1 is: def print_savings_details():. Line 2 is: print ("Name on account: ", name). Line 3 is: savings = salary - expense. Line 4 is: print ("Savings: ", savings). Line 5 is: print ("Interest rate: ", interest_rate). [Video description ends]
#
# So all of the references to the variables, name, salary, expense, and interest_rate refer to global variables. There are no local variables with the same name. This function is fairly straightforward. All it does is prints out the various bits of information, invoke this function, specify no input arguments, and the details are printed to screen.
#
# [Video description begins] The following code appears in code cell 3: print_savings_details(). Its output is: Name on account: James. Savings: 800. Interest rate: 0.04. [Video description ends]
#
# Now let's redefine the print_savings_details function. This time, we'll have this function taken four input arguments, name, salary, expense, and interest_rate.
#
# [Video description begins] Five code lines appear in code cell 4. Line 1 is: def print_savings_details (name, salary, expense, interest_rate):. [Video description ends]
#
# The function body prints out this information as it did before. But this time, the reference is to all of the variable names are to the local variables that are passed in as input argument, not to the global variables.
#
# [Video description begins] Line 2 is: print ("Name on account: ", name). Line 3 is: savings = salary - expense. Line 4 is: print ("Savings: ", savings). Line 5 is: print ("Interest rate: ",interest_rate). [Video description ends]
#
# Let's go ahead and invoke print_savings_details and pass in name, salary, expense, and interest_rate.
#
# [Video description begins] The following code appears in code cell 5: print_savings_details (name, salary, expense, interest_rate). [Video description ends]
#
# These are the global variables that we pass in as an input to this function. And all of the information is printed to screen.
#
# [Video description begins] Its output is: Name on account: James. Savings: 800. Interest rate: 0.04. [Video description ends]
#
# Everything that we've seen so far, you're familiar with, there's nothing really surprising here. I'm now going to invoke print_savings_details with a few different values. This is for Julie, her salary is 10,000, expense 2,000, interest rate 0.02.
#
# [Video description begins] The following code appears in code cell 6: print_savings_details("Julie",10000, 2000, 0.02). Its output is: Name on account: Julie. Savings: 8000. Interest rate: 0.02. [Video description ends]
#
# And Julie's information is what is printed out to screen from within our function. Now from within our function, I'm going to try and change the value of a variable passed in, print_savings_details, name, salary, expense, and interest_rate and observe that I have incremented the expense by a $100.
#
# [Video description begins] Six code lines appear in code cell 7. Line 1 is: def print_savings_details (name, salary, expense, interest_rate):. Line 3 is: expense = expense + 100. [Video description ends]
#
# Within the function body, I have said expense = expense + 100. I've changed the value assigned to the expense variable. Now, when you invoke print_savings_details, you'll see that the expenses have gone up, which is why our savings have fallen a bit.
#
# [Video description begins] The following code appears in code cell 8: print_savings_details (name, salary, expense, interest_rate). Its output is: Name on account: James. Savings: 700. Interest rate: 0.04. [Video description ends]
#
# But outside of the scope of the function, if you print out the current values for name, salary, expense, and interest_rate, you'll find that the changes that we made to the expense variable are not reflected outside of the function.
#
# [Video description begins] The following code appears in code cell 9: name, salary, expense, interest_rate. Its output is: ('James', 1000, 200, 0.04). [Video description ends]
#
# The expense here is still 200. It has not been incremented to 300. 200 was the original value that we assigned to the global expense variable. Changes that we make to a numeric variable within a function are not reflected outside of that function. This is what it means when we say that the argument expense has been passed into the function by value. I'm going to redefine the print_savings_details function.
#
# And this time, I'm going to change both the salary as well as the expense values within the function, salary = salary * 2, expense = expense + 100. In addition, I have reassigned name to be Harry and interest_rate to be 9%, 0.09. So I've changed the string variable, the integer variables, as well as the floating point variables.
#
# [Video description begins] Nine code lines appear in code cell 10. Line 2 is: name = "Harry". Line 4 is: salary = salary * 2. Line 5 is: expense = expense + 100. Line 8 is: interest_rate = 0.09. [Video description ends]
#
# Observe that all of these are primitive data types. I'm going to go ahead and invoke this function by using the global variables name, salary, expense, and interest_rate.
#
# [Video description begins] The following code appears in code cell 11: print_savings_details (name, salary, expense, interest_rate). [Video description ends]
#
# Changes that we make to the expense and salary variables within the function are visible only within the function. They do not affect the global variables. Observe that the name within the function is Harry. The expense is clearly increased by 100, and the salary has been multiplied by 2 and the interest rate is 0.09.
#
# [Video description begins] Its output is: Name on account: Harry. Savings: 1700. Interest rate: 0.09. [Video description ends]
#
# But if you look at name, salary, expense, and interest_rate outside of the function, they retain their old values.
#
# [Video description begins] The following code appears in code cell 12: name, salary, expense, interest_rate. Its output is: ('James', 1000, 200, 0.04). [Video description ends]
#
# This is because when you pass in primitive data types to a function, these arguments are passed by value. They are local variables. Changes that you make to the local variables are not reflected in the global variables. Let's take a look at some more code here. But this time, we'll work with a list, which is a complex data type.
#
# [Video description begins] The following code appears in code cell 13: fruits_list = ["Apple", "Grapes", "Mango", "Bananas"]. [Video description ends]
#
# Here is a list of fruits, and I'm going to pass this fruits_list into a function called change_list. Observe that within the change_list function, all I do is access the fruits_list variable which is passed in as an input argument and point the list to a new list.
#
# [Video description begins] Six code lines appear in code cell 14. Line 1 is: def change_list (fruits_list):. [Video description ends]
#
# The new list contains just Kiwi and Strawberry.
#
# [Video description begins] Line 2 is: fruits_list = ["Kiwi", "Strawberry"]. [Video description ends]
#
# I have a print statement within my change_list function which prints out the fruits_list inside the function.
#
# [Video description begins] Line 3 is: print ("Inside the function: ", fruits_list). [Video description ends]
#
# Now for code that is outside the function, I invoke change_list and pass in the fruits_list which contains Apple, Grapes, Mango, and Bananas.
#
# [Video description begins] Line 4 is: change_list (fruits_list). [Video description ends]
#
# Once Python has returned from the function call, I print out the current value of the fruits_list outside the function.
#
# [Video description begins] Line 5 is: print (). Line 6 is: print ("Outside the function: ", fruits_list). [Video description ends]
#
# Now let's go ahead and execute this and see what we get in the result. Observe that inside the function, fruits_list is Kiwi and Strawberry. Outside the function, it retains its old values, Apple, Grapes, Mango, and Bananas.
#
# [Video description begins] Two lines of output appear. Line 1 is: Inside the function: ['Kiwi', 'Strawberry']. Line 2 is: Outside the function: ['Apple', 'Grapes', 'Mango', 'Bananas']. [Video description ends]
#
# When we assign fruits_list to Kiwi and Strawberry within a function, this assignment did not affect the fruits_list outside the function. I'm now going to reassign fruits_list to Apple and Grapes outside the function.
#
# [Video description begins] The following code appears in code cell 15: fruits_list = ["Apple", "Grapes"]. [Video description ends]
#
# Then I'm going to invoke change_list and pass in this new fruits_list.
#
# [Video description begins] The following code appears in code cell 16: change_list (fruits_list). [Video description ends]
#
# Thanks to the assignment statement within the function inside the function, the fruits_list will be Kiwi and Strawberry.
#
# [Video description begins] Its output is: Inside the function: ['Kiwi', 'Strawberry']. [Video description ends]
#
# But outside the function, the fruits_list will contain Apple and Grapes.
#
# [Video description begins] The following code appears in code cell 17: fruits_list. Its output is: ['Apple', 'Grapes']. [Video description ends]
#
# **Passing by value means that when you reassign a list within a function, that reassignment or the creation of a new list does not affect the list outside the function. And you'll find that this is true for other complex data types such as tuples and dictionaries as well.**
#
# [Video description begins] The following code appears in code cell 18: fruits_tuple = ("Apple", "Grapes", "Mango", "Bananas"). [Video description ends]
#
# Here is a fruits_tuple, containing the same four fruits, Apple, Grapes, Mango, and Bananas. I have a change_tuple function which works in exactly the same way as the change_list function from earlier.
#
# [Video description begins] Six code lines appear in code cell 19. Line 1 is: def change_tuple (fruits_tuple):. [Video description ends]
#
# The fruits_tuple variable inside the function is assigned the tuple Kiwi and Strawberry.
#
# [Video description begins] Line 2 is: fruits_tuple = ("Kiwi", "Strawberry"). [Video description ends]
#
# We print out the value of the tuple inside the function and outside the function after change_tuple has been invoked.
#
# [Video description begins] Line 3 is: print ("Inside the function: ", fruits_tuple). Line 4 is: change_tuple(fruits_tuple). Line 5 is: print(). Line 6 is: print ("Outside the function: ", fruits_tuple). [Video description ends]
#
# And you can see that the new values that we assigned to the fruits_tuple is valid only inside the function. Outside the function, our fruits_tuple hasn't changed.
#
# [Video description begins] Two lines of output appear. Line 1 is: Inside the function: ('Kiwi', 'Strawberry'). Line 2 is: Outside the function: ('Apple', 'Grapes', 'Mango', 'Bananas'). [Video description ends]
#
# In fact, I'm going to redefine the change_tuple function and assign the fruits_tuple to a string, it's not even a tuple.
#
# [Video description begins] Six code lines appear in code cell 20. Line 2 is: fruits_tuple = "This is not even a tuple". [Video description ends]
#
# And you'll find that inside the function, the fruits_tuple is a string, outside the function, the tuple remains unchanged.
#
# [Video description begins] Two lines of output appear. Line 1 is: Inside the function: This is not even a tuple. Line 2 is: Outside the function: ('Apple', 'Grapes', 'Mango', 'Bananas'). [Video description ends]
#
# **You can see that fruits_tuple has been passed in by value. The value of the original tuple remains unchanged even though you've changed its value within the function. This is what passing by value means. Let's see one last example of passing a dictionary input argument by value. Here is a dictionary of car_speeds. I'm going to define a function called change_dictionary which takes as its input argument the dictionary, and then assigns the dictionary to an entirely new dictionary.**
#
# [Video description begins] Six code lines appear in code cell 21. Line 1 is: car_speeds_dictionary = {. Line 2 is: "Camry": 120,. Line 3 is: "Accord": 130,. Line 4 is: "Cayenne": 250,. Line 5 is: "Mini Cooper": 100. Line 6 is: }. [Video description ends]
#
# [Video description begins] Five code lines appear in code cell 22. Line 1 is: def change_dictionary (car_speeds_dictionary):. Line 2 is: car_speeds_dictionary = {. Line 3 is: "Mustang": 200. Line 4 is: }. Line 5 is: print ("Inside the function:", car_speeds_dictionary). [Video description ends]
#
# The new car_speeds_dictionary inside the function contains only information about the Mustang. Let's call change_dictionary by passing in our car_speeds_dictionary inside the function. The dictionary contains just Mustang.
#
# [Video description begins] The following code appears in code cell 23: change_dictionary (car_speeds_dictionary). Its output is: Inside the function:{'Mustang': 200}. [Video description ends]
#
# But this hasn't affected the car_speeds_dictionary outside the function.
#
# [Video description begins] The following code appears in code cell 24: car_speeds_dictionary. Its output is: {'Camry': 120, 'Accord': 130, 'Cayenne': 250, 'Mini Cooper': 100}. [Video description ends]
#
# **It contains values for all four cars. For both primitive and complex data types, when you reassign the values of these data types inside the function, you'll find that the variables outside the function remain unaffected this is what passing by value means.**
