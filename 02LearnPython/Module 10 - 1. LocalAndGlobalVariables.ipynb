# %%
country = "USA"
city = "Seattle"

# %%
def some_fn():
    print("Country: ", country)
    print("City: ", city)

# %%
some_fn()
# Out:
# Country:  USA
# City:  Seattle

# %%
def some_fn():
    country = "India"

    print("Country: ", country)
    print("City: ", city)

# %%
some_fn()
# Out:
# Country:  India
# City:  Seattle

# %%
country, city
# Out:
# ('USA', 'Seattle')

# %%
def some_fn():
    city = "Detroit"

    print("Country: ", country)
    print("City: ", city)

# %%
some_fn()
# Out:
# Country:  USA
# City:  Detroit

# %%
country, city
# Out:
# ('USA', 'Seattle')

# %%
def some_fn():
    country = "India"
    city = "Bangalore"

    print("Country: ", country)
    print("City: ", city)

# %%
some_fn()
# Out:
# Country:  India
# City:  Bangalore

# %%
country, city
# Out:
# ('USA', 'Seattle')

# %%
def some_fn():
    city = city + "-Washington"

    print("Country: ", country)
    print("City: ", city)

# %%
some_fn()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-14-c49aff4e3378> in <module>
# ----> 1 some_fn()
#
# <ipython-input-13-3f5351bd5594> in some_fn()
#       1 def some_fn():
# ----> 2     city = city + "-Washington"
#       3
#       4     print("Country: ", country)
#       5     print("City: ", city)
#
# UnboundLocalError: local variable 'city' referenced before assignment

# %%
def some_fn():
    city = "Seattle"
    city = city + "-Washington"

    print("Country: ", country)
    print("City: ", city)

# %%
some_fn()
# Out:
# Country:  USA
# City:  Seattle-Washington

# %%
country, city
# Out:
# ('USA', 'Seattle')

# %%
def some_fn():
    city = "San Francisco"
    city = city + "-California"

    print("Country: ", country)
    print("City: ", city)

# %%
some_fn()
# Out:
# Country:  USA
# City:  San Francisco-California

# %%
country, city
# Out:
# ('USA', 'Seattle')

# %%
def some_fn(country, city):
    print("Country: ", country)
    print("City: ", city)

# %%
some_fn("India", "Bangalore")
# Out:
# Country:  India
# City:  Bangalore

# %%
def some_fn():
    
    global city
    
    city = city + "-Washington"
    
    print("Country: ", country)
    print("City: ", city)

# %%
some_fn()
# Out:
# Country:  USA-World
# City:  Seattle-Washington-Washington

# %%
country, city
# Out:
# ('USA-World', 'Seattle-Washington-Washington')

# %%
city = "Seattle"

country, city
# Out:
# ('USA-World', 'Seattle')

# %%
def some_fn():
    
    global city, country
    
    city = city + "-Washington"
    country = country + "-World"
    
    print("Country: ", country)
    print("City: ", city)

# %%
some_fn()
# Out:
# Country:  USA-World-World
# City:  Seattle-Washington

# %%
country, city
# Out:
# ('USA-World-World', 'Seattle-Washington')
